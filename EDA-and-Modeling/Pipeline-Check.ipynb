# %% [markdown]
# # Evaluate and test the model pipeline
# #### The purpose of this notebook is to assess and test the model pipeline as standalone functions
# #### It also runs the politifact data.
# #### Author: Michael Denton
# #### Published Date: April 15, 2024

# %%
import pandas as pd
import os
import operator
from langgraph.graph import StateGraph, END
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser, StrOutputParser, CommaSeparatedListOutputParser
from langchain_community.llms import Ollama
from typing import TypedDict, Annotated, Sequence
from langchain_core.messages import BaseMessage
from langchain.tools import Tool
from langchain_community.utilities import GoogleSearchAPIWrapper
from langchain.agents import AgentType, initialize_agent, load_tools

from typing import List
from langchain.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
import json


def run_claim_judge_pipeline(text, search_version=0, one_claim = False, llm_to_use = 'mistral', baseline = False, study_mode = False):
    """
    Runs the judgement pipeline end to end

    Search API versions for Google: 
    - 0 = Entire web (v0)
    - 1 = politifact plus dictionaries (v1)
    - 2 = Just dictionaries (v2)
    - 3 = News sources (new york times, la times, washington post, economist, hbr)
    - 4 = .gov websites plus news sources (new york times, washington post, la times, reuters, bloomberg)
    - 5 = Entire web excluding politifact
    """

    # text = "Jupter is the smallest planet in the solar system."
    # search_version = 0
    # llm_to_use = 'mistral'
    
    # Keys removed for privacy reasons
    search_dict_for_keys = {
        0: "",
        1: "",
        2: "",
        3: "",
        4: "",
        5: "",
    }

    if search_version not in list(search_dict_for_keys.keys()):
        raise Exception('API search version not supported. Try one of 0,1,2,3.')


    # Set API key and CSE ID
    os.environ["GOOGLE_CSE_ID"] = search_dict_for_keys[search_version]
    os.environ["GOOGLE_API_KEY"] = ""
    # os.environ["TAVILY_API_KEY"] = ""

    if llm_to_use == 'llama2':
        llm = Ollama(model="llama2")
    elif llm_to_use == 'mistral':
        llm = Ollama(model="mistral-openorca")
    else:
        raise Exception('Selected LLM not supported')

    # Define the output parser
    string_parser = StrOutputParser()
    # json_parser = JsonOutputParser()
    list_parser = CommaSeparatedListOutputParser()

    claims_agent_messages = [
        ("system", "[INST]You are tasked with extracting the verifiable claims from the user query."),
        ("system", "Each claim should exist as a unique immutable string in a python list without any extras, like this:\n['first claim, 'second claim', 'third claim']\n"),
        ("system", "The domain focus is politics."),
        ("system", "One statement per claim."),
        ("user", "The user query:\n{input}\n"),
        ("system", "[/INST]")
    ]

    judge_agent_messages = [
        ("system", "[INST]You are tasked with judging whether the following claims are contained within the text."),
        ("system", "If these Claims, Facts, or Opinions are not in the original text, you will answer 'no'. If they are, answer 'yes'"),
        ("system", "The claims are:\n{extracted_claims}\n"),
        ("system", "These were claims from the following text:\n{input}\n"),
        ("system", "Are the claims are contained within the text? Answer only 'yes' or 'no' with no other text.[/INST]")
    ]

    feedback_agent_messages = [
        ("system", "Agents have assessed text for verifiable claims"),
        ("system", "A judge has compared these to the original text and decided that the extracted claims are not sufficient based on the original text."),
        ("system", "Given the analysis and the original text, provide instructions to improve the output."),
        ("user", "The verifiable claims are:\n{extracted_claims}\n"),
        ("user", "The origin text is:\n{input}\n"),
        ("user", "What changes should the agents implement?"),
    ]


    feedback_prompt = "You have previously done this before, and a judge has suggested the following notes to improve your answer: {reinforcer_notes}"


    # claims_agent = claims_agent_messages | llm | list_parser
    # judge_agent = judge_agent_messages | llm | list_parser

    # Define the agent state
    class AgentState(TypedDict):
        input_text: str
        claims_to_check: list[str]
        baseline: bool
        apiversion: int
        reinforcer_notes: str
        judge_output: str
        iteration: int
        max_iterations: int
        final_output: list
        responses: list

    def input(state):
        input_text = state["input_text"]
        
        return {"input_text": input_text}

    def is_one_sentence(state):
        """
        Checks if one sentence, if it is output go to search.
        Otherwise we'll parse out facts in each sentence
        """

        input_text = state["input_text"]
        if (len([val for val in str(input_text).replace('"','').replace("'",'').replace('\n','').replace('\t','').split('.') if val != '']) == 1) or one_claim:
            return 'go_to_search'
        return 'extract_claims_from_text'


    def extract_claims(state):
        input_text = state["input_text"]
        if state.get("reinforcer_notes"):
            claims_agent_messages.append(("system", feedback_prompt))
        reinforcer_notes = state.get("reinforcer_notes", "")

        claims_prompt = ChatPromptTemplate.from_messages(claims_agent_messages)
        claims_agent = claims_prompt | llm | list_parser
        response = claims_agent.invoke({"input": input_text, "reinforcer_notes": reinforcer_notes})
        print(response)
        # The format comes back as a list within a list
        if 'list' in str(type(response)).lower():
            
            if len(response) == 1:
                new_response = response[0]
            else:
                new_response = response

            if 'list' in str(type(new_response)).lower():
                if len(new_response) > 1:
                    formatted_responses = []
                    for val in new_response:
                        val = val.replace('[','').replace(']','').replace('<|im_end|>','')
                        if '\n' in val:
                            vals = val.split('\n')
                            formatted_responses = formatted_responses + vals
                        else:
                            formatted_responses.append(val)
                    response = formatted_responses
                

        return {"claims_to_check": response}

    def extract_judgement(state):
        formatted_extraction = state.get("claims_to_check")
        input = state.get("input_text")

        judge_prompt = ChatPromptTemplate.from_messages(judge_agent_messages)
        judge_agent = judge_prompt | llm | string_parser
        verdict = judge_agent.invoke({"input": input, "extracted_claims": formatted_extraction})
        print(verdict)
        if 'yes' in str(verdict).lower():
            verdict = 'yes'
        else:
            verdict = 'no'

        return {"judge_output": verdict}

    def feedback_on_incorrect_extractions(state):
        formatted_extraction = state.get("claims_to_check")
        input = state.get("input_text")
        instructor_prompt = ChatPromptTemplate.from_messages(feedback_agent_messages)
        instructor_agent = instructor_prompt | llm | string_parser
        instructions = instructor_agent.invoke({"input": input, "extracted_claims":formatted_extraction})
        return {"reinforcer_notes": instructions}                                                   

    def judge_happy(state):
        judges_verdict = state.get("judge_output")
        judges_verdict = judges_verdict.strip().replace("\n", "").lower()
        if judges_verdict == 'yes':
            return 'continue'
        return 'feedback'


    def google_search_agent(state):
        """
        AgentType
        """
        if state["claims_to_check"] is not None:
            claims_to_check = state["claims_to_check"] 
        else:
            claims_to_check = state["input_text"]

        if 'list' not in str(type(claims_to_check)).lower():
            claims_to_check = [claims_to_check]

        responses = []
        for clm in claims_to_check:
            print('checking',clm)
            responses.append(google_search_agent_call(stuff=clm, llm=llm, baseline=baseline))

        return {"responses": responses} 

    def print_output(state):
        responses = state.get("responses")

        return {"final_output": responses}

    graph = StateGraph(AgentState)

    # Define nodes in our graph

    graph.add_node("input", input)
    graph.add_node("claims_agent", extract_claims)
    graph.add_node("judge_agent", extract_judgement)
    graph.add_node("feedback_agent", feedback_on_incorrect_extractions)
    graph.add_node("search_agent", google_search_agent)
    graph.add_node("output", print_output)

    graph.add_conditional_edges(
        "input", 
        is_one_sentence, 
        {
            "go_to_search": "search_agent",
            "extract_claims_from_text": "claims_agent"
        }
    )
    graph.add_edge('claims_agent', 'judge_agent')
    graph.add_conditional_edges(
        "judge_agent",
        judge_happy,
        {
            "feedback": "feedback_agent",
            "continue": "search_agent"
        }
    )
    graph.add_edge('feedback_agent', 'claims_agent')
    graph.add_edge("search_agent", "output")
    graph.add_edge('output', END)

    graph.set_entry_point("input")

    verify = graph.compile()

    inputs = {"input_text": text}

    # for output in verify.stream(inputs):
    # # stream() yields dictionaries with output keyed by node name
    #     for key, value in output.items():
    #         print(f"Output from node '{key}':")
    #         print("---")
    #         print(value)
    #     print("\n---\n")

    return verify.invoke(inputs)


def google_search_agent_call(stuff, llm, study_mode=False, baseline=False):
    """
    Google search agent
    control_ouputs = None or a list of user defined outputs [example: user wants the llm to judge based on [yes, no, maybe, sometimes]]
    """

    examples = """
        The user query is : "The sky is blue". The output JSON is : 
        {
        "statement": "The sky is blue.",
        "judgement": "True",
        "justification": "The sky appears blue to the human eye, as it reflects the blue light of the atmosphere.",
        }, 

        The user query is : "Joseph Biden is the 46th president of the United States of America." The output JSON is :
        {
        "statement": "Joseph Biden is the 46th president of the United States of America.",
        "judgement": "True",
        "justification": "The White House website lists Joseph R. Biden Jr as the 46th president of the United States.",
        }, 

        The user query is : "Donald Trump won the 2020 United States Presidential Election." The output JSON is :
        {
        "statement": "Donald Trump won the 2020 United States Presidential Election.",
        "judgement": "False",
        "justification": "Donald Trump lost to Joe Biden in the 2020 presidential election by a count of 232 electoral votes to 306 for Joe Biden",
        },
    """
    
    class Judgement(BaseModel):
            
            statement: str = Field(description="The question or statement we are verifying.")
            judgement: str = Field(description="The judgement of the veracity of the question or statement.")
            justification: str = Field(description="The justification of the answer we have given.")

    json_parser = JsonOutputParser(pydantic_object=Judgement)
    string_parser = StrOutputParser()

    # Start timer
    import time
    start_time = time.time()

    if baseline:

        info = ''
        tool = None

    else:

        # set up google search
        info = ''
        tool = None
    
        search = GoogleSearchAPIWrapper()
        
        def top10_results(query):
            return search.results(query, 10)

        tool = Tool(
            name="google_search",
            description="Search Google for top 10 links.",
            func=top10_results,
        )

        # try:
        info = tool.invoke(stuff)
        # except:
        #     info = ''
    
    
    prompt = ChatPromptTemplate.from_messages([
            ("system","To answer the user query, provide a judgement on the truthfulness."),
            ("system","Use as few words as possible."),
            ("system","The correct format is a JSON: {format_instructions}"),
            ("system","The JSON output requires keys to include 'statement', 'judgement', 'justification'."),
            ("system","Here are some examples of the correct output: {example_output}"),
            ("system","Information from google search for context: {information}"),
            ("user","The user query is: {query}"),
            ("system","The output JSON is :")
    ])


    # f = open("temp.txt", "w")
    # f.writelines(str(info))
    # f.close()

    # print(info)
    try:
        search_agent = prompt | llm | json_parser
        res = search_agent.invoke(
            {"query":stuff, "information":info, "format_instructions":json_parser.get_format_instructions(), "example_output": examples}
        )

        if study_mode:
            print('First JSON output parser\n',res)

    except:

        if study_mode:
            print('JSON output parser failed.')

        search_agent = prompt | llm | string_parser
        res = search_agent.invoke(
            {"query":stuff, "information":info, "format_instructions":json_parser.get_format_instructions(), "example_output": examples}
        )

        if study_mode:
            print('First string output parser\n',res)

    # We have the result, now we need to convert into a dictionary object
    old_res = res
    if 'dict' not in str(type(res)).lower():
        if study_mode:
            print('Type was not a dictionary')
        try:
            res = eval('{'+res[res.find("{")+1:res.find("}")]+'}')
            
        except:
            if study_mode:
                print('Failed 1')   
            # Need to also consider the case of a nested dictionary, in which case this won't work.
            try:
                res = eval('{'+res[res.find("{")+1:res.find("}")]+'}'+'}') 
            except:
                
                try:
                    res = eval('{'+res[res.find("{")+1:res.find("}")]+'}]}')    
                except:
                    res = {}
    if study_mode:
        print(type(res))
    if 'dict' not in str(type(res)).lower():
        res = {}


    if ('statement' not in res.keys() or 'judgement' not in res.keys() or 'justification' not in res.keys()):

        max_tries = 6
        m=1
        new_res = None
        while (m < max_tries) and ('statement' not in res.keys() or 'judgement' not in res.keys() or 'justification' not in res.keys()):
            
            if study_mode:
                print(m)
            
            if len(res) == 0:
                last_res = old_res
            else:
                last_res = res


            new_prompt = ChatPromptTemplate.from_messages([
                ("system","Your original answer is missing key information required in the JSON output"),
                ("system","The JSON output requires keys to include 'statement', 'judgement', 'justification'"),
                ("system","The previous output was {last_result}"),
                ("system","Here are some examples of the correct output: {example_output}"),
                ("system","The correct format is a JSON: {format_instructions}"),
                ("user","The query to judge validity is:{query}"),
                ("user","The search information is:{info}"),
            ])

            try:
                search_agent = new_prompt | llm | json_parser
                new_res = search_agent.invoke(
                    {"query":stuff, "info":info, "format_instructions":json_parser.get_format_instructions(), "example_output": examples, "last_result":last_res}
                    )

                if study_mode:
                    print(new_res)

            except:
                search_agent = new_prompt | llm | string_parser
                new_res = search_agent.invoke(
                    {"query":stuff, "info":info, "format_instructions":json_parser.get_format_instructions(), "example_output": examples, "last_result":last_res}
                )

                if study_mode:
                    print(new_res)


            if 'dict' not in str(type(new_res)).lower():
                try:
                    new_res = eval('{'+new_res[new_res.find("{")+1:new_res.find("}")]+'}')
                except:
                    try:
                        new_res = eval('{'+new_res[new_res.find("{")+1:new_res.find("}")]+'}'+'}')
                    except:
                        old_res = new_res
                        new_res = {}

            if study_mode:
                print(new_res)

            if 'statement' in new_res.keys():
                if new_res['statement'] == '':
                    new_res.pop('statement')

            if 'justification' in new_res.keys():
                if new_res['justification'] == '':
                    new_res.pop('justification')

            if 'judgement' in new_res.keys():
                if new_res['judgement'] == '':
                    new_res.pop('judgement')

            if 'source' in new_res.keys():
                if new_res['source'] == '':
                    new_res.pop('source')

            if len(new_res) > 0:
                old_res = new_res
                res = new_res

            m+=1
        
    time_taken = time.time() - start_time

    res['process_time'] = time_taken
    res['information'] = str(info)
    res['message'] = "Successfully returned judgement"

    return res

# %%
text = """

The economic news in 2023 was almost miraculously good. Not only did America’s economy defy widespread predictions of recession, it also defied claims that only a significant rise in unemployment could bring inflation under control. Instead, we got a combination of strong growth, unemployment near a 50-year low and plunging inflation.

But last week, the Bureau of Labor Statistics reported that both the Consumer Price Index and the Producer Price Index rose 0.3 percent in January, more than most analysts expected. And the usual suspects — inflation perma-bears, political enemies of the Biden administration and economists who wrongly predicted that disinflation would require mass unemployment — jumped on the data as if it were a fumbled football.

So, are the good times over?

No. Everything we know suggests that those disappointing numbers were mostly a statistical blip rather than marking a significant worsening in inflation trends.

Before I explain how such blips can happen, let me tell you what indicators I was looking at after the inflation reports.

First, I was looking at financial markets, where instruments like inflation swaps and index bonds tell you what inflation rates investors putting real money on the line expect. The pricing on these instruments is still pointing to low inflation, around 2 percent or a bit more.

Second, I was waiting to see what happened in the Atlanta Federal Reserve’s survey of business inflation expectations, which asks businesses how much they expect costs to rise over the next year. If inflation were suddenly surging, you’d expect businesses to notice. But their inflation expectations rose to 2.3 percent in February from … 2.2 percent in January.

But if nothing much has changed, where did those slightly scary B.L.S. numbers come from?

In principle, the government estimates overall consumer prices the same way the American Farm Bureau Federation estimates the price of a classic Thanksgiving dinner (which was, by the way, down 4.5 percent in 2023): it calculates the cost of buying a fixed basket of goods and services.

In practice, our economy is a lot more complicated than a standardized holiday dinner menu, and estimating inflation involves a lot of fancy statistical footwork. The B.L.S. is extremely competent and professional — in fact, one rarely heralded policy advantage the United States has over other countries is that we generally have better data. But while I have nothing but praise for the bureau, its reports can still sometimes be misleading, for several reasons.

One reason is that to make sense of monthly data, you need to adjust for seasonal factors. Some of these factors are obvious: fresh vegetables get more expensive in the winter, cheaper in the summer. Others are less obvious. Goldman Sachs, which correctly predicted a bump in official inflation, points out that there is a “January effect” on prices, because many companies raise their prices at the beginning of the year. And Goldman argued, in advance, that the official numbers wouldn’t be sufficiently adjusted to reflect this effect, leading to a spurious bump in measured inflation — a bump that will vanish in the months ahead.

Goldman also pointed out that the single largest component in the Consumer Price Index — 27 percent of the basket! — is a price nobody actually pays: owners’ equivalent rent, an estimate of what homeowners would be paying if they rented their houses. There are reasons the bureau measures housing costs this way, but there are also reasons to believe that in recent years that number has become misleading, distorting and exaggerating estimates of overall inflation. As it happens, the B.L.S. also produces an estimate of prices excluding owners’ equivalent rent, roughly matching the way European countries measure inflation. This “harmonized” index is up only 2.3 percent over the past year.

If you find all of this a bit mind-numbing, let me tell you a secret — so do I, even though this is supposed to be my field. But the bottom line is important: Despite some disappointing numbers last week, the basic narrative hasn’t changed. The U.S. economy continues to look like an amazing success story.

Saying this leads, of course, to pushback from Republicans who’ve claimed ad nauseam that Biden’s “socialist” policies would be a disaster — and as I recently wrote, for such people believing is seeing, so they continue to insist that the economy is terrible even when by all objective measures, it’s doing pretty well. You also get some pushback from people on the left, who apparently believe that a progressive president shouldn’t be allowed to tout policy successes until he has completely eliminated poverty and insecurity — that is, never.

The fact, however, is that Biden has put in place a very ambitious agenda — major enhancements of Obamacare, student debt relief, big infrastructure spending, large-scale promotion of semiconductors and green energy that have led to a surge in manufacturing investment. Many voices warned that he was overreaching, that the economy would pay a big price.

But it hasn’t. It turns out that we can, in fact, afford to do a lot to improve Americans’ lives and invest in the future.


"""

# %%
# text = 'COVID-19 misinformation cost at least 2,800 lives and $300M, new reports says.'


out = run_claim_judge_pipeline(
    text=text, search_version=0, one_claim=False, llm_to_use = 'mistral', baseline=False, study_mode=True
    )

# print(out)

# %%
type(out)
# Out:
# dict

# %%
out.keys()
# Out:
# dict_keys(['input_text', 'claims_to_check', 'judge_output', 'responses', 'final_output'])

# %%
out['claims_to_check']
# Out:
# ['1. The economic news in 2023 was almost miraculously good with strong growth',
#  'unemployment near a 50-year low',
#  'and plunging inflation.',
#  '2. Inflation figures for January were higher than expected',
#  'but this is mostly a statistical blip rather than a significant worsening of inflation trends.',
#  '3. Financial markets indicate that investors still expect low inflation rates around 2 percent or slightly more.',
#  "4. The Atlanta Federal Reserve's survey of business inflation expectations rose to 2.3 percent in February from 2.2 percent in January.",
#  '5. Seasonal factors and the way housing costs are estimated can sometimes make inflation figures misleading',
#  'leading to temporary spikes in measured inflation.',
#  '6. Despite some disappointing numbers',
#  "the U.S. economy continues to look like an amazing success story with Biden's progressive agenda not causing the economic harm critics predicted."]

# %%
import json
with open('result.json', 'w') as fp:
    json.dump(out, fp)

# %%
import pprint

pprint.pp(out['final_output'])
# Out:
# [{'statement': 'COVID-19 misinformation cost at least 2,800 lives and $300M, '
#                'new report says.',
#   'judgement': 'True',
#   'justification': 'Recent reports have indicated that the spread of COVID-19 '
#                    'misinformation in Canada has cost at least 2800 lives and '
#                    '$300 million in hospital expenses over nine months.',
#   'process_time': 23.405393838882446,
#   'information': "[{'title': 'COVID-19 misinformation cost at least 2,800 "
#                  "lives and $300M, new ...', 'link': "
#                  "'https://www.cbc.ca/news/politics/cost-of-covid-19-misinformation-study-1.6726356', "
#                  "'snippet': 'Jan 27, 2023 ... The spread of COVID-19 "
#                  'misinformation in Canada cost at least 2800 lives and $300 '
#                  'million in hospital expenses over nine months of '
#                  "the\\xa0...'}, {'title': 'COVID misinformation led to at "
#                  "least 2800 deaths in Canada, $300M ...', 'link': "
#                  "'https://globalnews.ca/news/9438436/covid-misinformation-deaths-canada-report/', "
#                  "'snippet': 'Jan 26, 2023 ... Misinformation related to "
#                  'COVID-19 caused at least 2800 deaths, led to 13000 '
#                  'additional hospitalizations and cost hospitals $300 million '
#                  "in\\xa0...'}, {'title': 'Nova Scotia tight-lipped about "
#                  "spike in deaths | CBC News', 'link': "
#                  "'https://www.cbc.ca/news/canada/nova-scotia/excess-mortality-rate-causes-covid-19-1.6759698', "
#                  "'snippet': 'Mar 7, 2023 ... COVID-19 misinformation cost at "
#                  'least 2,800 lives and $300M, new report says. While Moriarty '
#                  "says deaths from COVID-19 are likely the biggest\\xa0...'}, "
#                  "{'title': 'Emma Quinn (@EmmaKQuinn) / X', 'link': "
#                  "'https://twitter.com/EmmaKQuinn', 'snippet': '... confident "
#                  'that those are conservative estimates." COVID-19 '
#                  'misinformation cost at least 2,800 lives and $300M, new '
#                  "report says | CBC News · From cbc.ca. 43. 122.'}, {'title': "
#                  "'Friday January 27, 2023 – mackaycartoons', 'link': "
#                  "'https://mackaycartoons.net/2023/01/27/friday-january-27-2023-2/', "
#                  "'snippet': 'Jan 27, 2023 ... COVID-19 misinformation cost at "
#                  'least 2,800 lives and $300M, new report says. August 7, '
#                  '2020. The spread of COVID-19 misinformation in '
#                  "Canada\\xa0...'}, {'title': 'Dr. Anni Sternisko "
#                  "(@AnniSternisko) / X', 'link': "
#                  "'https://twitter.com/annisternisko?lang=en', 'snippet': '... "
#                  'cost in lives around the world, public health, and the '
#                  'economy. COVID-19 misinformation cost at least 2,800 lives '
#                  "and $300M, new report says | CBC News · From\\xa0...'}, "
#                  "{'title': '2 is starting to make me just wanna play 1 : "
#                  "r/DragonsDogma', 'link': "
#                  "'https://www.reddit.com/r/DragonsDogma/comments/1btl667/2_is_starting_to_make_me_just_wanna_play_1/', "
#                  "'snippet': '6 days ago ... COVID-19 misinformation cost at "
#                  'least 2,800 lives and $300M, new report says · '
#                  'r/CanadaPolitics - COVID-19 misinformation cost at least '
#                  "2,800\\xa0...'}, {'title': 'Stefanie Mak, PhD (@stmkdesigns) "
#                  "/ X', 'link': 'https://twitter.com/stmkdesigns?lang=en', "
#                  "'snippet': '... expenses over nine months, according to "
#                  'estimates in a new report. COVID-19 misinformation cost at '
#                  "least 2,800 lives and $300M, new report says | CBC News.'}, "
#                  '{\'title\': "\'It\'s a pressure cooker\': Inside the chaos '
#                  'of Elon Musk\'s Twitter ...", \'link\': '
#                  "'https://www.reddit.com/r/Twitter/comments/11ng4uf/its_a_pressure_cooker_inside_the_chaos_of_elon/', "
#                  "'snippet': 'Mar 10, 2023 ... COVID-19 misinformation cost at "
#                  'least 2,800 lives and $300M, new report says · '
#                  'r/CanadianConservative - COVID-19 misinformation cost at '
#                  "least\\xa0...'}, {'title': 'Eric Ready (@Ready2Eric) / X', "
#                  "'link': 'https://twitter.com/Ready2Eric', 'snippet': "
#                  "'COVID-19 misinformation cost at least 2,800 lives and "
#                  '$300M, new report says. COVID-19 misinformation cost at '
#                  "least 2,800 lives and $300M, new report says.'}]",
#   'message': 'Successfully returned judgement'}]

# %% [markdown]
# ### Assess Accuracy against the politifact dataset

# %%
# Data has been previously web-scraped and is available in JSON format

import json
import pandas as pd

# path = ''
# fname = 'politifact_3000.json'

# f = open(path+fname)
# data = json.load(f)

# politifact_scraped_data = pd.DataFrame()

# j=0
# for i in data:
#     temp = {}
#     # if j==0:
#     for key in i.keys():
#         temp[key] = str(i[key])

#     politifact_scraped_data = pd.concat([politifact_scraped_data, pd.DataFrame(data=temp, index=[j])])
#     j+=1
 
# f.close()

# politifact_scraped_data.to_excel('politifact_scraped_data.xlsx')

politifact_scraped_data = pd.read_excel('politifact_scraped_data.xlsx')
# sampled_data = pd.read_excel('sampled_subset_of_poltifact_data.xlsx')
previous_judged = pd.read_excel('sampled_data_merged.xlsx')

# %%
politifact_scraped_data.head(2)
# Out:
#    index                                              claim     claim_source  \
# 0      0  Michael Moore is supporting Trump in the 2024 ...  Instagram posts
# 1      1  The 2022 CHIPS and Science Act “attracted $640...        Joe Biden
#
#          review_date   review_author     veracity  \
# 0      March 4, 2024     Sofia Ahmed        false
# 1  February 29, 2024  Louis Jacobson  barely-true
#
#                                          review_tags  \
# 0    ['Elections', 'Pop Culture', 'Instagram posts']
# 1  ['National', 'Science', 'Technology', 'Joe Bid...
#
#                                        review_points  \
# 0  ['In a longer video of the 2016 documentary "M...
# 1  ['A Semiconductor Industry Association analysi...
#
#                                       review_article  \
# 0  Michael Moore, a liberal filmmaker, did not an...
# 1  Ahead of his 2024 State of the Union address, ...
#
#                                           review_url
# 0  https://www.politifact.com/factchecks/2024/mar...
# 1  https://www.politifact.com/factchecks/2024/feb...

# %%
politifact_scraped_data['veracity'].value_counts()
# Out:
# veracity
# false          1781
# pants-fire      539
# barely-true     261
# half-true       173
# mostly-true     157
# true             71
# full-flop        12
# half-flip         6
# Name: count, dtype: int64

# %%
politifact_scraped_data = politifact_scraped_data[~politifact_scraped_data['veracity'].isin(['full-flop','half-flip'])]

# %%
# replace later
saved_dataframe = previous_judged

max_n = int(100 / 6)

samples = []
for veracity, veracity_data in politifact_scraped_data.groupby('veracity'):

    veracity_data = veracity_data[~veracity_data['index'].isin(saved_dataframe['index'])]

    if len(veracity_data) > 0:
        samples.append(veracity_data.sample(n=max_n, replace=True))

# %%
sampled_data = pd.concat(samples)
sampled_data.describe()
# Out:
#              index
# count    96.000000
# mean   1649.166667
# std     778.053613
# min      89.000000
# 25%    1110.500000
# 50%    1740.500000
# 75%    2239.750000
# max    2992.000000

# %%
sampled_data.sort_values(by='index').head()
# Out:
#      index                                              claim    claim_source  \
# 89      89  “Wisconsin had over 1,400 opioid overdose deat...   Tammy Baldwin
# 165    165  Gov. Tony Evers and Democrats "rejected our (I...       Robin Vos
# 195    195  Wisconsin Republicans are backing “a nonpartis...      Ron Tusler
# 225    225  In Florida, “any woman who has an abortion aft...    Gavin Newsom
# 252    252  U.S. Rep. Mike Johnson is the 45th speaker of ...  Facebook posts
#
#            review_date   review_author     veracity  \
# 89    February 6, 2024   Laura Schulte         true
# 165  December 22, 2023  Vanessa Swales  mostly-true
# 195   December 8, 2023      D.L. Davis    half-true
# 225  November 29, 2023     Amy Sherman    half-true
# 252   November 3, 2023  Ciara O'Rourke        false
#
#                                            review_tags  \
# 89   ['Drugs', 'Public Health', 'Wisconsin', 'Tammy...
# 165  ['Redistricting', 'States', 'Iowa', 'Wisconsin...
# 195  ['Redistricting', 'States', 'Iowa', 'Wisconsin...
# 225  ['Abortion', 'Crime', 'California', 'Florida',...
# 252         ['Facebook Fact-checks', 'Facebook posts']
#
#                                          review_points  \
# 89   ['The number of people who died from opioids i...
# 165  ['Wisconsin Legislative Reference Bureau says ...
# 195  ['The Iowa model refers to a redistricting met...
# 225  ['Florida Gov. Ron DeSantis signed a bill in A...
# 252  ['U.S. Rep. Mike Johnson is the 56th speaker o...
#
#                                         review_article  \
# 89   The number of opioid deaths has been steadily ...
# 165  The State of Wisconsin’s redistricting process...
# 195  Iowa has played an outsized role in presidenti...
# 225  California’s Democratic Gov. Gavin Newsom and ...
# 252   U.S. Rep. Mike Johnson, R-La., was elected sp...
#
#                                             review_url
# 89   https://www.politifact.com/factchecks/2024/feb...
# 165  https://www.politifact.com/factchecks/2023/dec...
# 195  https://www.politifact.com/factchecks/2023/dec...
# 225  https://www.politifact.com/factchecks/2023/nov...
# 252  https://www.politifact.com/factchecks/2023/nov...

# %%
# for i,row in sampled_data.iterrows():
#     print(row['index'])
#     print('>',row['claim'])
#     print('')

# %%
previous_judged.sort_values(by='index').head()
# Out:
#    Unnamed: 0.1  index                                              claim  \
# 0             0     30  “Marijuana is currently classified in the same...
# 1             1     44  President Joe Biden “directed New York AG Witc...
# 2             2     65  "(The) top issue for college students is the e...
# 3             3    105  Donald Trump “proposed when he was president” ...
# 4             4    156  Jimmy Kimmel was on the Jeffrey Epstein list, ...
#
#          claim_source        review_date   review_author     veracity  \
# 0  Kirsten Gillibrand  February 20, 2024  Conor Amendola         true
# 1        Donald Trump  February 20, 2024  Louis Jacobson        false
# 2        Scott Walker   February 2, 2024    Hope Karnopp         true
# 3         Nikki Haley   January 19, 2024  Louis Jacobson  barely-true
# 4             X posts    January 4, 2024    Jeff Cercone   pants-fire
#
#                                          review_tags  \
# 0  ['Drugs', 'Public Health', 'New York', 'Kirste...
# 1  ['National', 'Legal Issues', 'New York', 'Dona...
# 2  ['Abortion', 'Economy', 'Education', 'Wisconsi...
# 3  ['New Hampshire', 'Infrastructure', 'Taxes', '...
# 4  ['National', 'Criminal Justice', 'Facebook Fac...
#
#                                        review_points  \
# 0  ['Sen. Kirsten Gillibrand, D-N.Y., is correct ...
# 1  ['Letitia James said during her 2018 campaign ...
# 2  ['Polling commissioned by Young America’s Foun...
# 3  ['While president, Donald Trump expressed luke...
# 4  ['Comedian and TV host Jimmy Kimmel was not me...
#
#                                       review_article  \
# 0  When Sen. Kirsten Gillibrand, D-N.Y., shared a...
# 1  Following a $355 million court ruling against ...
# 2  In the lead-up to the 2024 election, president...
# 3  ROCHESTER, N.H. — In the Republican presidenti...
# 4  The first 40 of more than 200 court documents ...
#
#                                           review_url  Unnamed: 0  \
# 0  https://www.politifact.com/factchecks/2024/feb...          27
# 1  https://www.politifact.com/factchecks/2024/feb...          23
# 2  https://www.politifact.com/factchecks/2024/feb...          25
# 3  https://www.politifact.com/factchecks/2024/jan...           0
# 4  https://www.politifact.com/factchecks/2024/jan...           7
#
#                                            judgement  API judgement_answer  \
# 0  [{'statement': 'Marijuana is currently classif...    0             true
# 1  [{'statement': 'President Joe Biden “directed ...    0            false
# 2  [{'statement': '(The) top issue for college st...    0             true
# 3  [{'statement': 'Donald Trump “proposed when he...    0            false
# 4  [{'statement': 'Jimmy Kimmel was on the Jeffre...    0            false
#
#                                              sources
# 0  [{'title': 'Yes, the federal government still ...
# 1  [{'title': "Fact-check: Trump's baseless claim...
# 2  [{'title': "PolitiFact: Most college voters' N...
# 3  [{'title': 'Nikki Haley said Donald Trump want...
# 4  [{'title': 'Jimmy Kimmel on X: "Dear Aasshole:...

# %%
sampled_data = sampled_data.drop_duplicates(subset=['claim']).reset_index(drop=True)

# %%
sampled_data['veracity'].value_counts()
# Out:
# veracity
# false          16
# pants-fire     16
# barely-true    15
# mostly-true    15
# true           15
# half-true      14
# Name: count, dtype: int64

# %%
# # Provide judgement
# sampled_data = pd.read_csv('politifact_judged_v1.csv')

# def run_function_wrapper(x, apiv):
#     try:
#         out = run_claim_judge_pipeline(
#             text=x['claim'], one_claim=True, search_version=apiv, llm_to_use = 'mistral', outputs = None, baseline=False, study_mode=True
#         )
#         return out
#     except Exception as e:
#         print(e)
#         return None

# # sampled_data['jugdement_api_v4'] = sampled_data.apply(lambda x: run_function_wrapper(x, apiv=4), axis=1)
# sampled_data['jugdement_api_v0'] = sampled_data.apply(lambda x: run_function_wrapper(x, apiv=0), axis=1)

# %%
#sampled_data_merged = pd.read_excel('sampled_data_merged.xlsx')
# sampled_data[(~sampled_data['index'].isin(indxs)) & (~sampled_data['index'].isin(spanish))][['index','claim']].to_excel('test.xlsx')

# %%
spanish = [126, 85, 2983, 2504, 2600]
indxs = []
res_v0= []

for i,row in sampled_data[(~sampled_data['index'].isin(indxs)) & (~sampled_data['index'].isin(spanish))][['index','claim']].iterrows():

    try:
        out_v0 = run_claim_judge_pipeline(
                text=row['claim'], one_claim = True, search_version=0, llm_to_use = 'mistral', study_mode=False
        )
        indxs.append(row['index'])
        res_v0.append(out_v0['final_output'])
    except Exception as e:
        print(e)
        indxs.append(row['index'])
        res_v0.append(None)

judged_politifact_v0 = pd.DataFrame(data={'index': indxs, 'judgement': res_v0, 'API': 0})
judged_politifact_v0.head()

judged_politifact_v0.to_excel('judged_subset_of_politifact_data_part4.xlsx')
# Out:
# checking Says Tim Michels' family foundation "funded an organization that tracks women when they get near abortion clinics … he wants to treat women like they're the criminals."
# checking Raphael Warnock "believes in no cash bail" and "letting people out of prison that are going to make us prisoners in our own home."
# checking Cheri Beasley “backs tax hikes — even on families making under $75,000.”
# checking Says Gov. Tony Evers would, “allow the government to use red flag laws to confiscate your firearms without due process.”
# checking “Mandela Barnes came out in favor of abortion up until the moment of birth.”
# checking "38,000 Texans had their license to carry denied, revoked, or suspended over the last five years because law enforcement deemed them too dangerous to carry a loaded gun in public. But thanks to Greg Abbott's new law, they don't need a license to carry anymore."
# checking "Kari Lake has been appearing at rallies with neo-Nazis," while "two federal juries have found" Katie Hobbs "guilty of racial discrimination."
# checking “We have 76% of Americans living paycheck to paycheck, meaning they are one paycheck away from poverty.”
# checking As with people vaccinated against COVID-19, “many people who were NOT vaccinated also experienced zero or mild symptoms.”
# checking "Derrick Van Orden is one of the only members of Congress who participated in the deadly January 6th insurrection. He now serves in the building he tried to burn down."
# checking California has twice the population of New York, but spends $260 billion, while New York spends $220 billion.
# checking “Joe Biden’s war on American energy caused this crisis and his only response has been to drain our strategic petroleum reserve to its lowest level since 1983.”
# checking "As Ohio treasurer, Josh Mandel loaned your money to Chinese business interests, and Mandel opposed a bill holding Communist China accountable when they cheated and stole American jobs."
# checking Fuel containing 15% ethanol will ruin a car engine.
# checking Says Gov. Tony Evers would, “allow the government to use red flag laws to confiscate your firearms without due process.”
# checking ABC News altered the Uvalde, Texas, school shooter’s photo to appear more Caucasian.
# checking Georgia Gov. Brian Kemp “allowed 7.5 million ballots to be sent to every registered voter.”
# checking Aaron Salter Jr. was killed by a mass shooter because he was working on creating a water-powered car engine.
# checking “Any American who needs $2,000 a month can get it now” thanks to a new government program.
# checking A video shows people holding up their phones to film President Joe Biden, but “every phone there is turned off.”
# checking “Every single Republican blocked Ketanji Brown Jackson’s SCOTUS appointment.”
# checking Says New Zealand Prime Minister Jacinda Ardern said her country doesn’t have to deal with the “rage of older white men” because “we’ve never allowed Rupert Murdoch to set up a media outlet here.”
# checking California state Sen. Scott Wiener “doesn’t just want to sterilize California kids, but sterilization of kids everywhere!”
# checking They passed the flu off as COVID-19, and “they’re going to do the same thing with monkeypox and shingles.”
# checking Video shows Elon Musk said South Africans no longer have to work with access to his “platform.”
# checking World Economic Forum “calls for AI to rewrite Bible, create ‘religions that are actually correct’”
# checking “Scientists warn eggs are causing thousands of people to ‘suddenly’ form blood clots.”
# checking U.S. Rep. Mike Johnson is the 45th speaker of the House.
# checking Emergency stimulus loans “are finally available to U.S. citizens up to $5,000 even with poor credit.”
# checking The Pelosis “are refusing to turn over surveillance video of their home.”
# checking In Ohio, “there are 75,000 acres of farmland, fertile farmland, that are all now being poured down with acid rain.”
# checking When discussing education savings accounts, "We would be 31st in the nation to have these policies going forward on behalf of kids.”
# checking There is “$500 billion of unspent COVID money” that can be rescinded.
# checking Raphael Warnock and Catherine Cortez Masto “voted to allow hundreds of millions of dollars of COVID relief funds to be squandered” on leisure projects.
# checking “We’re one of the seven nations in the world that allow abortion on demand at 20 weeks.”
# checking “Gas prices have skyrocketed since Joe Biden took office and continue to do so everyday.”
# checking Adam Laxalt "supports eliminating Nevada's protections for legal abortions."
# checking “The nonpartisan Congressional Budget Office says with the supersized staff, the IRS audit rate ‘would rise for ALL taxpayers’ regardless of income, and would even result in audits of innocent Americans who have paid their taxes and don’t owe the IRS anything.”
# checking “Jen Kiggans’ campaign confirmed today that she would support a national abortion ban.”
# checking "We've cut the deficit by a record $1.5 trillion this year."
# checking “Iowans are paying $5,000 extra for everyday goods under Biden and Axne’s inflation.”
# checking Four North Carolina Republicans made “campaign promises” to protect reproductive rights
# checking “We’re one of the seven nations in the world that allow abortion on demand at 20 weeks.”
# checking Wisconsin Republicans are backing “a nonpartisan redistricting plan based off the Iowa Model. ... Republicans, Democrats, and the Governor pushed this plan last time redistricting happened in 2020.”
# checking In Florida, “any woman who has an abortion after six weeks — and any doctor who gives her care — will be guilty of a felony.”
# checking “In every other major industrial country in the world … inflation is higher.”
# checking U.S. aid to Ukraine will continue during a government shutdown, but programs for food stamps, transportation, education, justice, environmental protection and homelessness will not.
# checking U.S. inflation is "now down close to 3%, the lowest among the world’s leading economies."
# checking Gov. Tony Evers and Democrats "rejected our (Iowa model redistricting) proposal to enact the very plan they originally endorsed."
# checking “The USA has a gun homicide rate 26 times higher than our peers.”
# checking If a 12-year-old girl became pregnant because of rape or incest, "Tim Michels would force her to deliver the baby."
# checking U.S. inflation is "now down close to 3%, the lowest among the world’s leading economies."
# checking “Every single county in New York has experienced a federal climate disaster between 2011-2021.”
# checking Walgreens’ position “has always been” to “dispense Mifepristone in any jurisdiction where it is legally permissible to do so.”
# checking “In the last 11 months, Customs and Border Patrol has averaged 200,000 apprehensions a month, and you know how many beds we have to detain people at the border? Thirty-eight thousand."
# checking "As compared to last year, Texas has about 15% more power generation capacity."
# checking Katie Hobbs “has voted to double our gas tax.”
# checking "As compared to last year, Texas has about 15% more power generation capacity."
# checking Sen. Marco Rubio has "one of the worst attendance records in the Senate."
# checking Florida “decided middle school students will be taught that enslaved people benefited from slavery.”
# checking “Texas Republicans just voted to give a Republican appointee the power to single-handedly CANCEL election results in the state’s largest Democratic county.”
# checking Sen. Marco Rubio and U.S. Rep. Ron DeSantis “voted against aid for Hurricane Sandy.”
# checking Canada is to thank for American football.
# checking Video shows U.S. Secret Service agents are demons.
# checking “Trump controls U.S. military.”
# checking Drone footage confirms Jeffrey Epstein is alive.
# checking President Joe Biden and Democrats "send a fortune to Ukraine but nothing for our children."
# checking In Arizona, early voting would allow Kari Lake’s opponents to see how many votes they “need to fake to catch up and surpass.”
# checking Hitler “didn’t kill 6 million Jews” and “the Holocaust is not what happened.”
# checking Queen Elizabeth II was a reptile.
# checking “Cocaine, porn, evidence of child trafficking found in (Gov. Gretchen) Whitmer’s car.”
# checking Jackie Chan is dead.
# checking Regarding Trump’s January 2021 telephone call with Georgia election officials, “nobody found anything wrong with that perfect call until a book promotion tour many months later.”
# checking Says Marjorie Taylor Greene said “246 years ago Jesus Christ performed his miracle of making a single days worth of bullets last 8 days.”
# checking Taylor Swift was photographed holding a “Trump won, Democrats cheated!” flag at the Grammy Awards.
# checking In the 2018 Florida governor's race "votes were being stolen by the corrupt election process in Broward. … I sent in the FBI and the U.S. Attorneys, and the ballot theft immediately ended. … I stopped his Election from being stolen."
# checking Pouring soda on raw pork will cause parasites to emerge.
# checking Barack Obama urged people on Sept. 10, 2001, to “report to work tomorrow” at the World Trade Center.
# checking "Historically, our spring elections (including for state Supreme Court) have a smaller turnout associated with them."
# checking Minnesota incarcerates “about a third of what Wisconsin does.”
# checking Says expanding Medicaid in Wisconsin would save the state $530 million, which could pay for 3,287 K-12 teachers, or 7.8 educators per district.
# checking We’ve reduced crime to its lowest level in 27 years.
# checking “Lego donates model MRI kits to hospitals to help children understand the procedure and reduce their anxiety.”
# checking “New York leads the U.S. in population loss.”
# checking "In the Wisconsin State Assembly this session, more than 75% of GOP bills received a public hearing. Meanwhile, the GOP allowed less than 2% of Democratic bills to have a hearing."
# checking Cannabis reform "is supported by the majority of the residents of our state, including a majority of Republicans."
# checking “For African American families in particular, the homeownership rate remains relatively unchanged since 1968, the year the Fair Housing Act was signed into law.”
# checking “New York leads the U.S. in population loss.”
# checking "WOW county swing suburban voters (in Wisconsin) don't vote for Donald Trump.”
# checking David Schweikert has “been convicted of 11 House ethics violations.”
# checking “Wisconsin had over 1,400 opioid overdose deaths in 2022.”
# checking “In April last year, our state unemployment rate hit a record low of 2.4%. Last year, Wisconsin had an all-time lowest number of unemployed workers ever in modern history.”
# checking "40% of the folks who have student loans do not have a college diploma, four-year diploma. These are people who are truck drivers and who are nail technicians and nurses’ aides.”
# checking Image claims to show a list of "Republican members of Congress whose PPP loans were forgiven."

# %% [markdown]
# ### Evaluate the models
# - Must run and save to a list so that when the google API runs out of credits, the information is saved

# %%
sampled_data = pd.read_excel('sampled_data_merged.xlsx')
print(len(sampled_data.drop_duplicates(subset='claim')))
# Out:
# 206

# %%
indxs_apiv5 = []
res_apiv5 = []

spanish = [126, 85, 2983, 2504, 2600]
for i,row in sampled_data[(~sampled_data['index'].isin(indxs_apiv5)) & (~sampled_data['index'].isin(spanish))][['index','claim']].iterrows():
    
    print(i)
    try:
        out_v0 = run_claim_judge_pipeline(
                text=row['claim'], one_claim = True, search_version=5, llm_to_use = 'mistral', study_mode=False, baseline=False
        )
        indxs_apiv5.append(row['index'])
        res_apiv5.append(out_v0['final_output'])
    except Exception as e:
        print(e)
        indxs_apiv5.append(row['index'])
        res_apiv5.append(None)

judged_politifact_apiv5 = pd.DataFrame(data={'index': indxs_apiv5, 'judgement': res_apiv5, 'API': 5})
judged_politifact_apiv5.head()

judged_politifact_apiv5.to_excel('judged_subset_of_politifact_data_apiv5.xlsx')
# Out:
# 0
# checking “Marijuana is currently classified in the same category of drugs as heroin and a more dangerous category than fentanyl or cocaine.”
# 1
# checking President Joe Biden “directed New York AG Witch Hunt” into Donald Trump’s real estate.
# 2
# checking "(The) top issue for college students is the economy."
# 3
# checking “Wisconsin had over 1,400 opioid overdose deaths in 2022.”
# 4
# checking Donald Trump “proposed when he was president” that “he wanted to raise the gas tax up to 25 cents."
# 5
# checking Jimmy Kimmel was on the Jeffrey Epstein list, documents show.
# 6
# checking “Right now, over 70% of federal employees are still working from home three years after COVID."
# 7
# checking Gov. Tony Evers and Democrats "rejected our (Iowa model redistricting) proposal to enact the very plan they originally endorsed."
# 8
# checking Wisconsin Republicans are backing “a nonpartisan redistricting plan based off the Iowa Model. ... Republicans, Democrats, and the Governor pushed this plan last time redistricting happened in 2020.”
# 9
# checking Republicans’ “plan would cut Social Security benefits. … Average benefit cut would be 13%.”
# 10
# checking In Florida, “any woman who has an abortion after six weeks — and any doctor who gives her care — will be guilty of a felony.”
# 11
# checking Potato chips, KitKat bars and Viagra are not taxed in Wisconsin because they are considered "essential."
# 12
# checking U.S. Rep. Mike Johnson is the 45th speaker of the House.
# 13
# checking “In the last 11 months, Customs and Border Patrol has averaged 200,000 apprehensions a month, and you know how many beds we have to detain people at the border? Thirty-eight thousand."
# 14
# checking "Derrick Van Orden is one of the only members of Congress who participated in the deadly January 6th insurrection. He now serves in the building he tried to burn down."
# 15
# checking “Trump controls U.S. military.”
# 16
# checking “Gas prices have skyrocketed since Joe Biden took office and continue to do so everyday.”
# 17
# checking Foreign languages are “not a high priority” nationally
# 18
# checking “The percentage of students that are going to college (in West Virginia) has been declining for five years.”
# 19
# checking Since Joe Biden “has taken office, unemployment in our (Latino) community has been cut in half."
# 20
# checking U.S. aid to Ukraine will continue during a government shutdown, but programs for food stamps, transportation, education, justice, environmental protection and homelessness will not.
# 21
# checking “We know the bank records show that nearly $20 million in payments were directed to the Biden family members and associates through various shell companies.”
# 22
# checking Under Gov. Ron DeSantis, “in the last five years, spending has gone up 30%" in Florida.
# 23
# checking “You can work at some McDonald’s in this country for more money than … signing up for the military.”
# 24
# checking Florida “decided middle school students will be taught that enslaved people benefited from slavery.”
# 25
# checking "Tejas, Florida y otros estados acaban de anunciar que le darán papeles a todos los inmigrantes indocumentados".
# 26
# checking A video shows people holding up their phones to film President Joe Biden, but “every phone there is turned off.”
# 27
# checking World Economic Forum “calls for AI to rewrite Bible, create ‘religions that are actually correct’”
# 28
# checking “Cocaine, porn, evidence of child trafficking found in (Gov. Gretchen) Whitmer’s car.”
# 29
# checking “For African American families in particular, the homeownership rate remains relatively unchanged since 1968, the year the Fair Housing Act was signed into law.”
# 30
# checking Four North Carolina Republicans made “campaign promises” to protect reproductive rights
# 31
# checking Emergency stimulus loans “are finally available to U.S. citizens up to $5,000 even with poor credit.”
# 32
# checking "There is no Biden presidency. The real Biden was executed for his crimes long ago along with Clinton."
# 33
# checking "WOW county swing suburban voters (in Wisconsin) don't vote for Donald Trump.”
# 34
# checking Video shows Sen. Chris Murphy running away because Sen. Ted Cruz said “just shut your mouth.”
# 35
# checking Video shows a crowd erupting and Hillary Clinton crying during a committee hearing.
# 36
# checking "The First Amendment doesn’t allow you to willingly lie."
# 37
# checking "Businesses large and small have led Texas to be ranked the number one state for business every year that I’ve been governor."
# 38
# checking “Harry could be exiled to Botswana after he was deported from the United States due to an expired visa.”
# 39
# checking In Ohio, “there are 75,000 acres of farmland, fertile farmland, that are all now being poured down with acid rain.”
# 40
# checking The sinking of the Titanic was orchestrated by the Rothschilds and J.P. Morgan to kill prominent businessmen who opposed the creation of the Federal Reserve.
# 41
# checking “Classified documents can never be taken out of a (sensitive compartmented information facility), ever.”
# 42
# checking California has twice the population of New York, but spends $260 billion, while New York spends $220 billion.
# 43
# checking Magic Johnson tested positive for HIV "because Fauci’s gain of function study used a contaminated Hepatitis B vaccine."
# 44
# checking “Every single Republican blocked Ketanji Brown Jackson’s SCOTUS appointment.”
# 45
# checking “When the Republicans were in power the last time for eight years, do you know how much discretionary spending increased in those eight years? Zero.”
# 46
# checking Recent blood clots or strokes in four major athletes are an unwanted effect of COVID-19 vaccines.
# 47
# checking Raphael Warnock "believes in no cash bail" and "letting people out of prison that are going to make us prisoners in our own home."
# 48
# checking Photo shows “ballots not counted in California and this is only one polling location. Yet Gavin Newsom was declared governor minutes after polling stations closed.”
# 49
# checking President Joe Biden and Democrats "send a fortune to Ukraine but nothing for our children."
# 50
# checking Katie Hobbs “has voted to double our gas tax.”
# 51
# checking The Pelosis “are refusing to turn over surveillance video of their home.”
# 52
# checking California state Sen. Scott Wiener “doesn’t just want to sterilize California kids, but sterilization of kids everywhere!”
# 53
# checking Catherine Cortez Masto "was the deciding vote” to send COVID-19 stimulus checks to more than 1 million prisoners.
# 54
# checking Says Tim Michels "opposes closing the loophole that allows domestic abusers to buy guns."
# 55
# checking “Mandela Barnes came out in favor of abortion up until the moment of birth.”
# 56
# checking Donald Trump’s “rally just got shut down after no one shows up.”
# 57
# checking Val Demings "voted to allow transgender youth sports and teaching radical gender identity without parental consent."
# 58
# checking “The Obama Foundation stored classified documents in an abandoned furniture warehouse.”
# 59
# checking Sen. Marco Rubio and U.S. Rep. Ron DeSantis “voted against aid for Hurricane Sandy.”
# 60
# checking “Jen Kiggans’ campaign confirmed today that she would support a national abortion ban.”
# 61
# checking “Since 2019, I've successfully lobbied for the funds to add hundreds of school counselors, lowering our student to school counselor ratio by 20%.”
# 62
# checking Says Tim Michels' family foundation "funded an organization that tracks women when they get near abortion clinics … he wants to treat women like they're the criminals."
# 63
# checking “This year, it's going to be over $1.5 trillion (that we’ve) reduced the debt."
# 64
# checking "40% of the folks who have student loans do not have a college diploma, four-year diploma. These are people who are truck drivers and who are nail technicians and nurses’ aides.”
# 65
# checking "Last year the IRS audited Americans earning less than $25,000 a year at five times the rate of other groups."
# 66
# checking Says Republican U.S. Sen. Ron Johnson “called climate change ‘bull----’ during a record heatwave” and “raked in over $700k in fossil fuel cash.”
# 67
# checking Raphael Warnock and Catherine Cortez Masto “voted to allow hundreds of millions of dollars of COVID relief funds to be squandered” on leisure projects.
# 68
# checking "We've cut the deficit by a record $1.5 trillion this year."
# 69
# checking "38,000 Texans had their license to carry denied, revoked, or suspended over the last five years because law enforcement deemed them too dangerous to carry a loaded gun in public. But thanks to Greg Abbott's new law, they don't need a license to carry anymore."
# 70
# checking Video shows Donald Trump at an Alabama rally on July 13, 2022.
# 71
# checking CNN coverage has evidence of the “single most egregious, real-time example of electronic vote fraud.”
# 72
# checking "Milwaukee’s hotels and restaurants are already filled during the summer. The RNC convention will simply replace those who normally visit our city."
# 73
# checking Video claims Moscow turned into “sea of fire after being attacked by two mysterious missiles.”
# 74
# checking Video shows Russian artillery tanks “completely destroyed by Bayraktar TB2 drones” on July 2.
# 75
# checking “When you have unemployment below 4% and inflation above 4%, recession always follows within two years.”
# 76
# checking Says Marjorie Taylor Greene said “246 years ago Jesus Christ performed his miracle of making a single days worth of bullets last 8 days.”
# 77
# checking “In every other major industrial country in the world … inflation is higher.”
# 78
# checking “Wisconsin's archaic abortion ban is older than 20 states."
# 79
# checking Recent research suggests that 15% of abortions are the result of coercion.
# 80
# checking Adam Laxalt "supports eliminating Nevada's protections for legal abortions."
# 81
# checking “In Virginia, Black people are eight times (8X) more likely than white people to die of gun homicide.”
# 82
# checking “Zack Nunn saved over 2,000 Americans abandoned in Afghanistan by leading private rescue missions.”
# 83
# checking CNN is recycling crisis actors in reports about a man dying in Afghanistan in 2021 and at the Uvalde, Texas, school shooting in 2022.
# 84
# checking Aaron Salter Jr. was killed by a mass shooter because he was working on creating a water-powered car engine.
# 85
# checking In 2013, under a Democratic Senate, "a majority of the Senate voted in favor of" gun-related legislation sponsored by Republican Sens. Chuck Grassley and Ted Cruz, “but the Democrats filibustered it.”
# 86
# checking Increased encounters at the southwest border in April 2022 compared to April 2020 are attributable to changes in border policy.
# 87
# checking "David Perdue voted with liberals” for $10 trillion “in new debt, his out-of-control federal spending is driving inflation through the roof."
# 88
# checking “We have 76% of Americans living paycheck to paycheck, meaning they are one paycheck away from poverty.”
# 89
# checking Images show Joe Biden surrounded by U.S. Marshals.
# 90
# checking “79% of Planned Parenthood clinics are in minority neighborhoods. This is not by accident. That is by its founder, Margaret Sanger's, eugenicist design."
# 91
# checking “We’re one of the seven nations in the world that allow abortion on demand at 20 weeks.”
# 92
# checking "Kari Lake has been appearing at rallies with neo-Nazis," while "two federal juries have found" Katie Hobbs "guilty of racial discrimination."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%22Kari+Lake+has+been+appearing+at+rallies+with+neo-Nazis%2C%22+while+%22two+federal+juries+have+found%22+Katie+Hobbs+%22guilty+of+racial+discrimination.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 93
# checking Jackie Chan is dead.
# 94
# checking "Pfizer tries to hide 2.4K full-time hires handling vax injuries."
# 95
# checking “The student debt that is out there, almost 60% of it is graduate school debt.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CThe+student+debt+that+is+out+there%2C+almost+60%25+of+it+is+graduate+school+debt.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 96
# checking “The Red Cross sells your donated blood to hospitals for $150 and then that hospital charges you thousands for a blood transfusion.”
# 97
# checking “Just passed into law today: You cannot go 5 miles over speed limit” in North Carolina.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CJust+passed+into+law+today%3A+You+cannot+go+5+miles+over+speed+limit%E2%80%9D+in+North+Carolina.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 98
# checking As with people vaccinated against COVID-19, “many people who were NOT vaccinated also experienced zero or mild symptoms.”
# 99
# checking "As compared to last year, Texas has about 15% more power generation capacity."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%22As+compared+to+last+year%2C+Texas+has+about+15%25+more+power+generation+capacity.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 100
# checking Says New Zealand Prime Minister Jacinda Ardern said her country doesn’t have to deal with the “rage of older white men” because “we’ve never allowed Rupert Murdoch to set up a media outlet here.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Says+New+Zealand+Prime+Minister+Jacinda+Ardern+said+her+country+doesn%E2%80%99t+have+to+deal+with+the+%E2%80%9Crage+of+older+white+men%E2%80%9D+because+%E2%80%9Cwe%E2%80%99ve+never+allowed+Rupert+Murdoch+to+set+up+a+media+outlet+here.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 101
# checking March 2022 moon crash was orchestrated by the government and visible from Earth.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=March+2022+moon+crash+was+orchestrated+by+the+government+and+visible+from+Earth.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 102
# checking Fuel containing 15% ethanol will ruin a car engine.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Fuel+containing+15%25+ethanol+will+ruin+a+car+engine.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 103
# checking “Most Americans favor keeping Title 42 in place.”
# 104
# checking "As Ohio treasurer, Josh Mandel loaned your money to Chinese business interests, and Mandel opposed a bill holding Communist China accountable when they cheated and stole American jobs."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%22As+Ohio+treasurer%2C+Josh+Mandel+loaned+your+money+to+Chinese+business+interests%2C+and+Mandel+opposed+a+bill+holding+Communist+China+accountable+when+they+cheated+and+stole+American+jobs.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 105
# checking Since taking office, Hochul has passed more than 400 new bills
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Since+taking+office%2C+Hochul+has+passed+more+than+400+new+bills&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 106
# checking Cannabis reform "is supported by the majority of the residents of our state, including a majority of Republicans."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Cannabis+reform+%22is+supported+by+the+majority+of+the+residents+of+our+state%2C+including+a+majority+of+Republicans.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 107
# checking We’ve reduced crime to its lowest level in 27 years.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=We%E2%80%99ve+reduced+crime+to+its+lowest+level+in+27+years.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 108
# checking “New York leads the U.S. in population loss.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CNew+York+leads+the+U.S.+in+population+loss.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 109
# checking Videos show that Ukraine President Volodymyr Zelenskyy uses cocaine.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Videos+show+that+Ukraine+President+Volodymyr+Zelenskyy+uses+cocaine.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 110
# checking “Kathy Barnette wants to build a statue of Barack Obama right next to the one of Abraham Lincoln on Capitol Hill."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CKathy+Barnette+wants+to+build+a+statue+of+Barack+Obama+right+next+to+the+one+of+Abraham+Lincoln+on+Capitol+Hill.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 111
# checking Georgia Gov. Brian Kemp “allowed 7.5 million ballots to be sent to every registered voter.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Georgia+Gov.+Brian+Kemp+%E2%80%9Callowed+7.5+million+ballots+to+be+sent+to+every+registered+voter.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 112
# checking ABC News altered the Uvalde, Texas, school shooter’s photo to appear more Caucasian.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=ABC+News+altered+the+Uvalde%2C+Texas%2C+school+shooter%E2%80%99s+photo+to+appear+more+Caucasian.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 113
# checking Texas is "50th in the nation in mental health care access."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Texas+is+%2250th+in+the+nation+in+mental+health+care+access.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 114
# checking They passed the flu off as COVID-19, and “they’re going to do the same thing with monkeypox and shingles.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=They+passed+the+flu+off+as+COVID-19%2C+and+%E2%80%9Cthey%E2%80%99re+going+to+do+the+same+thing+with+monkeypox+and+shingles.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 115
# checking “Florida Highway Patrol has a semi-truck … The FHP uses a fleet of three such ‘hidden in plain sight’ trucks to snitch on bad drivers.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CFlorida+Highway+Patrol+has+a+semi-truck+%E2%80%A6+The+FHP+uses+a+fleet+of+three+such+%E2%80%98hidden+in+plain+sight%E2%80%99+trucks+to+snitch+on+bad+drivers.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 116
# checking “The majority of citizens in the country will have no change at all because … most of the population resides in states that have already protected abortion rights.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CThe+majority+of+citizens+in+the+country+will+have+no+change+at+all+because+%E2%80%A6+most+of+the+population+resides+in+states+that+have+already+protected+abortion+rights.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 117
# checking The Supreme Court decision overturning Roe v. Wade "made the United States an outlier among developed nations in the world" on abortion rights.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=The+Supreme+Court+decision+overturning+Roe+v.+Wade+%22made+the+United+States+an+outlier+among+developed+nations+in+the+world%22+on+abortion+rights.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 118
# checking Photo shows U.S. Rep. Lauren Boebert with two scantily dressed men.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Photo+shows+U.S.+Rep.+Lauren+Boebert+with+two+scantily+dressed+men.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 119
# checking “The four big meat packers are raking in record profits … ”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CThe+four+big+meat+packers+are+raking+in+record+profits+%E2%80%A6+%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 120
# checking “SCOTUS overturned the 2020 election.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CSCOTUS+overturned+the+2020+election.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 121
# checking The Wisconsin Supreme Court decision declaring ballot drop boxes illegal "includes the 2020 Presidential Election."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=The+Wisconsin+Supreme+Court+decision+declaring+ballot+drop+boxes+illegal+%22includes+the+2020+Presidential+Election.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 122
# checking Sen. Marco Rubio has "one of the worst attendance records in the Senate."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Sen.+Marco+Rubio+has+%22one+of+the+worst+attendance+records+in+the+Senate.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 123
# checking "In the Wisconsin State Assembly this session, more than 75% of GOP bills received a public hearing. Meanwhile, the GOP allowed less than 2% of Democratic bills to have a hearing."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%22In+the+Wisconsin+State+Assembly+this+session%2C+more+than+75%25+of+GOP+bills+received+a+public+hearing.+Meanwhile%2C+the+GOP+allowed+less+than+2%25+of+Democratic+bills+to+have+a+hearing.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 124
# checking "They are literally chopping off the private parts of young kids."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%22They+are+literally+chopping+off+the+private+parts+of+young+kids.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 125
# checking Image claims to show a list of "Republican members of Congress whose PPP loans were forgiven."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Image+claims+to+show+a+list+of+%22Republican+members+of+Congress+whose+PPP+loans+were+forgiven.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 126
# checking There’s an unlimited supply of water being generated “deep within the Earth.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=There%E2%80%99s+an+unlimited+supply+of+water+being+generated+%E2%80%9Cdeep+within+the+Earth.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 127
# checking Queen Elizabeth II was a reptile.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Queen+Elizabeth+II+was+a+reptile.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 128
# checking “The nonpartisan Congressional Budget Office says with the supersized staff, the IRS audit rate ‘would rise for ALL taxpayers’ regardless of income, and would even result in audits of innocent Americans who have paid their taxes and don’t owe the IRS anything.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CThe+nonpartisan+Congressional+Budget+Office+says+with+the+supersized+staff%2C+the+IRS+audit+rate+%E2%80%98would+rise+for+ALL+taxpayers%E2%80%99+regardless+of+income%2C+and+would+even+result+in+audits+of+innocent+Americans+who+have+paid+their+taxes+and+don%E2%80%99t+owe+the+IRS+anything.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 129
# checking Photo shows Queen Elizabeth II meeting Donald Trump wearing a brooch given to her by Barack Obama.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Photo+shows+Queen+Elizabeth+II+meeting+Donald+Trump+wearing+a+brooch+given+to+her+by+Barack+Obama.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 130
# checking Barack Obama urged people on Sept. 10, 2001, to “report to work tomorrow” at the World Trade Center.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Barack+Obama+urged+people+on+Sept.+10%2C+2001%2C+to+%E2%80%9Creport+to+work+tomorrow%E2%80%9D+at+the+World+Trade+Center.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 131
# checking "Val Demings supports abortion up until the moment of birth."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%22Val+Demings+supports+abortion+up+until+the+moment+of+birth.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 132
# checking Three court rulings since May 2022 “have made it clear that it is unconstitutional to ban someone between the ages of 18 and 20 from being able to buy an AR.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Three+court+rulings+since+May+2022+%E2%80%9Chave+made+it+clear+that+it+is+unconstitutional+to+ban+someone+between+the+ages+of+18+and+20+from+being+able+to+buy+an+AR.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 133
# checking Every time a Republican has been elected president over the last few decades, House Democrats have objected to the result
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Every+time+a+Republican+has+been+elected+president+over+the+last+few+decades%2C+House+Democrats+have+objected+to+the+result&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 134
# checking Ballot harvesting “altered the outcome” of a city council election in Yuma County, Arizona.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Ballot+harvesting+%E2%80%9Caltered+the+outcome%E2%80%9D+of+a+city+council+election+in+Yuma+County%2C+Arizona.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 135
# checking Herschel Walker misled about “personally treating 4,500 veterans per year,” about “graduating from college” and about “working in law enforcement.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Herschel+Walker+misled+about+%E2%80%9Cpersonally+treating+4%2C500+veterans+per+year%2C%E2%80%9D+about+%E2%80%9Cgraduating+from+college%E2%80%9D+and+about+%E2%80%9Cworking+in+law+enforcement.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 136
# checking “Iowans are paying $5,000 extra for everyday goods under Biden and Axne’s inflation.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CIowans+are+paying+%245%2C000+extra+for+everyday+goods+under+Biden+and+Axne%E2%80%99s+inflation.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 137
# checking Lee County, Florida, wasn't "even in the cone" of Hurricane Ian 72 hours before landfall.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Lee+County%2C+Florida%2C+wasn%27t+%22even+in+the+cone%22+of+Hurricane+Ian+72+hours+before+landfall.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 138
# checking U.S. Sen. Marco Rubio "has denied climate change."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=U.S.+Sen.+Marco+Rubio+%22has+denied+climate+change.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 139
# checking If a 12-year-old girl became pregnant because of rape or incest, "Tim Michels would force her to deliver the baby."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=If+a+12-year-old+girl+became+pregnant+because+of+rape+or+incest%2C+%22Tim+Michels+would+force+her+to+deliver+the+baby.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 140
# checking In Arizona, early voting would allow Kari Lake’s opponents to see how many votes they “need to fake to catch up and surpass.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=In+Arizona%2C+early+voting+would+allow+Kari+Lake%E2%80%99s+opponents+to+see+how+many+votes+they+%E2%80%9Cneed+to+fake+to+catch+up+and+surpass.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 141
# checking Adam Laxalt is “anti-DACA” and “fought against the protections for DACA recipients when he was attorney general.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Adam+Laxalt+is+%E2%80%9Canti-DACA%E2%80%9D+and+%E2%80%9Cfought+against+the+protections+for+DACA+recipients+when+he+was+attorney+general.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 142
# checking Rep. Tim Ryan “wanted to decriminalize fentanyl.”
# ...
# 186
# checking U.S. inflation is "now down close to 3%, the lowest among the world’s leading economies."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=U.S.+inflation+is+%22now+down+close+to+3%25%2C+the+lowest+among+the+world%E2%80%99s+leading+economies.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 187
# checking Sen. Rick Scott “wants to … end Social Security and Medicare coverage.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Sen.+Rick+Scott+%E2%80%9Cwants+to+%E2%80%A6+end+Social+Security+and+Medicare+coverage.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 188
# checking The World Economic Forum is calling “for COVID concentration camps.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=The+World+Economic+Forum+is+calling+%E2%80%9Cfor+COVID+concentration+camps.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 189
# checking There are "about a half a dozen" transgender athletes competing in Wisconsin K-12 schools.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=There+are+%22about+a+half+a+dozen%22+transgender+athletes+competing+in+Wisconsin+K-12+schools.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 190
# checking “Lego donates model MRI kits to hospitals to help children understand the procedure and reduce their anxiety.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CLego+donates+model+MRI+kits+to+hospitals+to+help+children+understand+the+procedure+and+reduce+their+anxiety.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 191
# checking “Because of our economic policies we now are reducing inflation.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CBecause+of+our+economic+policies+we+now+are+reducing+inflation.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 192
# checking Video shows Elon Musk said South Africans no longer have to work with access to his “platform.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Video+shows+Elon+Musk+said+South+Africans+no+longer+have+to+work+with+access+to+his+%E2%80%9Cplatform.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 193
# checking Video shows “Israel Zionist blowing up people in hospitals” in 2023.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Video+shows+%E2%80%9CIsrael+Zionist+blowing+up+people+in+hospitals%E2%80%9D+in+2023.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 194
# checking “Any American who needs $2,000 a month can get it now” thanks to a new government program.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CAny+American+who+needs+%242%2C000+a+month+can+get+it+now%E2%80%9D+thanks+to+a+new+government+program.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 195
# checking New Hampshire has “a worse drug problem per capita than any other state."
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=New+Hampshire+has+%E2%80%9Ca+worse+drug+problem+per+capita+than+any+other+state.%22&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 196
# checking “Last year alone, natural disasters in America caused $178 billion in damages.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CLast+year+alone%2C+natural+disasters+in+America+caused+%24178+billion+in+damages.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 197
# checking "Los estadounidenses que ganan menos de $50,000 al año pueden solicitar un seguro médico gratuito".
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%22Los+estadounidenses+que+ganan+menos+de+%2450%2C000+al+a%C3%B1o+pueden+solicitar+un+seguro+m%C3%A9dico+gratuito%22.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 198
# checking "La administración acaba de aprobar este vacío legal, 100% legal, que permite a todos los residentes estadounidenses en buena posición obtener un permiso de portación oculta (de armas) válido en 2023".
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%22La+administraci%C3%B3n+acaba+de+aprobar+este+vac%C3%ADo+legal%2C+100%25+legal%2C+que+permite+a+todos+los+residentes+estadounidenses+en+buena+posici%C3%B3n+obtener+un+permiso+de+portaci%C3%B3n+oculta+%28de+armas%29+v%C3%A1lido+en+2023%22.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 199
# checking “Florida state government (has the) lowest number of state employees per capita in the country.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CFlorida+state+government+%28has+the%29+lowest+number+of+state+employees+per+capita+in+the+country.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 200
# checking Taylor Swift was photographed holding a “Trump won, Democrats cheated!” flag at the Grammy Awards.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Taylor+Swift+was+photographed+holding+a+%E2%80%9CTrump+won%2C+Democrats+cheated%21%E2%80%9D+flag+at+the+Grammy+Awards.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 201
# checking Under Joe Biden, there are “record numbers of new Black entrepreneurs.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Under+Joe+Biden%2C+there+are+%E2%80%9Crecord+numbers+of+new+Black+entrepreneurs.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 202
# checking Minnesota incarcerates “about a third of what Wisconsin does.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Minnesota+incarcerates+%E2%80%9Cabout+a+third+of+what+Wisconsin+does.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 203
# checking Says expanding Medicaid in Wisconsin would save the state $530 million, which could pay for 3,287 K-12 teachers, or 7.8 educators per district.
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Says+expanding+Medicaid+in+Wisconsin+would+save+the+state+%24530+million%2C+which+could+pay+for+3%2C287+K-12+teachers%2C+or+7.8+educators+per+district.&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 204
# checking “In April last year, our state unemployment rate hit a record low of 2.4%. Last year, Wisconsin had an all-time lowest number of unemployed workers ever in modern history.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CIn+April+last+year%2C+our+state+unemployment+rate+hit+a+record+low+of+2.4%25.+Last+year%2C+Wisconsin+had+an+all-time+lowest+number+of+unemployed+workers+ever+in+modern+history.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# 205
# checking “We’ve seen an 800% increase in the Swanton sector, which is the part of the northern border that I represent, in illegal crossings.”
# <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%E2%80%9CWe%E2%80%99ve+seen+an+800%25+increase+in+the+Swanton+sector%2C+which+is+the+part+of+the+northern+border+that+I+represent%2C+in+illegal+crossings.%E2%80%9D&cx=90a9a70ca0052432c&num=10&key=AIzaSyDPtBvSXiWGW5I6vPiaAL9LTip2AUX_MsY&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:289895840326'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">

# %%
# judged_politifact_apiv5 = pd.DataFrame(data={'index': indxs_apiv5, 'judgement': res_apiv5, 'API': 'baseline-mistral7b'})
# judged_politifact_apiv5.head()

# judged_politifact_apiv5.to_excel('judged_subset_of_politifact_data_apiv5.xlsx')

# %%
indxs_baseline_m7 = []
res_baseline_m7 = []

for i,row in sampled_data.iterrows():
    
    print(i)
    try:
        out_v0 = run_claim_judge_pipeline(
                text=row['claim'], one_claim = True, search_version=0, llm_to_use = 'mistral', study_mode=False, baseline=True
        )
        indxs_baseline_m7.append(row['index'])
        res_baseline_m7.append(out_v0['final_output'])
    except Exception as e:
        print(e)
        indxs_baseline_m7.append(row['index'])
        res_baseline_m7.append(None)

judged_politifact_baseline_m7 = pd.DataFrame(data={'index': indxs_baseline_m7, 'judgement': res_baseline_m7, 'API': 'baseline-mistral7b'})
judged_politifact_baseline_m7.head()

judged_politifact_baseline_m7.to_excel('judged_subset_of_politifact_data_mistral7b_baseline.xlsx')
# Out:
# 0
# checking “Marijuana is currently classified in the same category of drugs as heroin and a more dangerous category than fentanyl or cocaine.”
# 1
# checking President Joe Biden “directed New York AG Witch Hunt” into Donald Trump’s real estate.
# 2
# checking "(The) top issue for college students is the economy."
# 3
# checking “Wisconsin had over 1,400 opioid overdose deaths in 2022.”
# 4
# checking Donald Trump “proposed when he was president” that “he wanted to raise the gas tax up to 25 cents."
# 5
# checking Jimmy Kimmel was on the Jeffrey Epstein list, documents show.
# 6
# checking “Right now, over 70% of federal employees are still working from home three years after COVID."
# 7
# checking Gov. Tony Evers and Democrats "rejected our (Iowa model redistricting) proposal to enact the very plan they originally endorsed."
# 8
# checking Wisconsin Republicans are backing “a nonpartisan redistricting plan based off the Iowa Model. ... Republicans, Democrats, and the Governor pushed this plan last time redistricting happened in 2020.”
# 9
# checking Republicans’ “plan would cut Social Security benefits. … Average benefit cut would be 13%.”
# 10
# checking In Florida, “any woman who has an abortion after six weeks — and any doctor who gives her care — will be guilty of a felony.”
# 11
# checking Potato chips, KitKat bars and Viagra are not taxed in Wisconsin because they are considered "essential."
# 12
# checking U.S. Rep. Mike Johnson is the 45th speaker of the House.
# 13
# checking “In the last 11 months, Customs and Border Patrol has averaged 200,000 apprehensions a month, and you know how many beds we have to detain people at the border? Thirty-eight thousand."
# 14
# checking "Derrick Van Orden is one of the only members of Congress who participated in the deadly January 6th insurrection. He now serves in the building he tried to burn down."
# 15
# checking “Trump controls U.S. military.”
# 16
# checking “Gas prices have skyrocketed since Joe Biden took office and continue to do so everyday.”
# 17
# checking Foreign languages are “not a high priority” nationally
# 18
# checking “The percentage of students that are going to college (in West Virginia) has been declining for five years.”
# 19
# checking Since Joe Biden “has taken office, unemployment in our (Latino) community has been cut in half."
# 20
# checking U.S. aid to Ukraine will continue during a government shutdown, but programs for food stamps, transportation, education, justice, environmental protection and homelessness will not.
# 21
# checking “We know the bank records show that nearly $20 million in payments were directed to the Biden family members and associates through various shell companies.”
# 22
# checking Under Gov. Ron DeSantis, “in the last five years, spending has gone up 30%" in Florida.
# 23
# checking “You can work at some McDonald’s in this country for more money than … signing up for the military.”
# 24
# checking Florida “decided middle school students will be taught that enslaved people benefited from slavery.”
# 25
# checking "Tejas, Florida y otros estados acaban de anunciar que le darán papeles a todos los inmigrantes indocumentados".
# 26
# checking A video shows people holding up their phones to film President Joe Biden, but “every phone there is turned off.”
# 27
# checking World Economic Forum “calls for AI to rewrite Bible, create ‘religions that are actually correct’”
# 28
# checking “Cocaine, porn, evidence of child trafficking found in (Gov. Gretchen) Whitmer’s car.”
# 29
# checking “For African American families in particular, the homeownership rate remains relatively unchanged since 1968, the year the Fair Housing Act was signed into law.”
# 30
# checking Four North Carolina Republicans made “campaign promises” to protect reproductive rights
# 31
# checking Emergency stimulus loans “are finally available to U.S. citizens up to $5,000 even with poor credit.”
# 32
# checking "There is no Biden presidency. The real Biden was executed for his crimes long ago along with Clinton."
# 33
# checking "WOW county swing suburban voters (in Wisconsin) don't vote for Donald Trump.”
# 34
# checking Video shows Sen. Chris Murphy running away because Sen. Ted Cruz said “just shut your mouth.”
# 35
# checking Video shows a crowd erupting and Hillary Clinton crying during a committee hearing.
# 36
# checking "The First Amendment doesn’t allow you to willingly lie."
# 37
# checking "Businesses large and small have led Texas to be ranked the number one state for business every year that I’ve been governor."
# 38
# checking “Harry could be exiled to Botswana after he was deported from the United States due to an expired visa.”
# 39
# checking In Ohio, “there are 75,000 acres of farmland, fertile farmland, that are all now being poured down with acid rain.”
# 40
# checking The sinking of the Titanic was orchestrated by the Rothschilds and J.P. Morgan to kill prominent businessmen who opposed the creation of the Federal Reserve.
# 41
# checking “Classified documents can never be taken out of a (sensitive compartmented information facility), ever.”
# 42
# checking California has twice the population of New York, but spends $260 billion, while New York spends $220 billion.
# 43
# checking Magic Johnson tested positive for HIV "because Fauci’s gain of function study used a contaminated Hepatitis B vaccine."
# 44
# checking “Every single Republican blocked Ketanji Brown Jackson’s SCOTUS appointment.”
# 45
# checking “When the Republicans were in power the last time for eight years, do you know how much discretionary spending increased in those eight years? Zero.”
# 46
# checking Recent blood clots or strokes in four major athletes are an unwanted effect of COVID-19 vaccines.
# 47
# checking Raphael Warnock "believes in no cash bail" and "letting people out of prison that are going to make us prisoners in our own home."
# 48
# checking Photo shows “ballots not counted in California and this is only one polling location. Yet Gavin Newsom was declared governor minutes after polling stations closed.”
# 49
# checking President Joe Biden and Democrats "send a fortune to Ukraine but nothing for our children."
# 50
# checking Katie Hobbs “has voted to double our gas tax.”
# 51
# checking The Pelosis “are refusing to turn over surveillance video of their home.”
# 52
# checking California state Sen. Scott Wiener “doesn’t just want to sterilize California kids, but sterilization of kids everywhere!”
# 53
# checking Catherine Cortez Masto "was the deciding vote” to send COVID-19 stimulus checks to more than 1 million prisoners.
# 54
# checking Says Tim Michels "opposes closing the loophole that allows domestic abusers to buy guns."
# 55
# checking “Mandela Barnes came out in favor of abortion up until the moment of birth.”
# 56
# checking Donald Trump’s “rally just got shut down after no one shows up.”
# 57
# checking Val Demings "voted to allow transgender youth sports and teaching radical gender identity without parental consent."
# 58
# checking “The Obama Foundation stored classified documents in an abandoned furniture warehouse.”
# 59
# checking Sen. Marco Rubio and U.S. Rep. Ron DeSantis “voted against aid for Hurricane Sandy.”
# 60
# checking “Jen Kiggans’ campaign confirmed today that she would support a national abortion ban.”
# 61
# checking “Since 2019, I've successfully lobbied for the funds to add hundreds of school counselors, lowering our student to school counselor ratio by 20%.”
# 62
# checking Says Tim Michels' family foundation "funded an organization that tracks women when they get near abortion clinics … he wants to treat women like they're the criminals."
# 63
# checking “This year, it's going to be over $1.5 trillion (that we’ve) reduced the debt."
# 64
# checking "40% of the folks who have student loans do not have a college diploma, four-year diploma. These are people who are truck drivers and who are nail technicians and nurses’ aides.”
# 65
# checking "Last year the IRS audited Americans earning less than $25,000 a year at five times the rate of other groups."
# 66
# checking Says Republican U.S. Sen. Ron Johnson “called climate change ‘bull----’ during a record heatwave” and “raked in over $700k in fossil fuel cash.”
# 67
# checking Raphael Warnock and Catherine Cortez Masto “voted to allow hundreds of millions of dollars of COVID relief funds to be squandered” on leisure projects.
# 68
# checking "We've cut the deficit by a record $1.5 trillion this year."
# 69
# checking "38,000 Texans had their license to carry denied, revoked, or suspended over the last five years because law enforcement deemed them too dangerous to carry a loaded gun in public. But thanks to Greg Abbott's new law, they don't need a license to carry anymore."
# 70
# checking Video shows Donald Trump at an Alabama rally on July 13, 2022.
# 71
# checking CNN coverage has evidence of the “single most egregious, real-time example of electronic vote fraud.”
# 72
# checking "Milwaukee’s hotels and restaurants are already filled during the summer. The RNC convention will simply replace those who normally visit our city."
# 73
# checking Video claims Moscow turned into “sea of fire after being attacked by two mysterious missiles.”
# 74
# checking Video shows Russian artillery tanks “completely destroyed by Bayraktar TB2 drones” on July 2.
# 75
# checking “When you have unemployment below 4% and inflation above 4%, recession always follows within two years.”
# 76
# checking Says Marjorie Taylor Greene said “246 years ago Jesus Christ performed his miracle of making a single days worth of bullets last 8 days.”
# 77
# checking “In every other major industrial country in the world … inflation is higher.”
# 78
# checking “Wisconsin's archaic abortion ban is older than 20 states."
# 79
# checking Recent research suggests that 15% of abortions are the result of coercion.
# 80
# checking Adam Laxalt "supports eliminating Nevada's protections for legal abortions."
# 81
# checking “In Virginia, Black people are eight times (8X) more likely than white people to die of gun homicide.”
# 82
# checking “Zack Nunn saved over 2,000 Americans abandoned in Afghanistan by leading private rescue missions.”
# 83
# checking CNN is recycling crisis actors in reports about a man dying in Afghanistan in 2021 and at the Uvalde, Texas, school shooting in 2022.
# 84
# checking Aaron Salter Jr. was killed by a mass shooter because he was working on creating a water-powered car engine.
# 85
# checking In 2013, under a Democratic Senate, "a majority of the Senate voted in favor of" gun-related legislation sponsored by Republican Sens. Chuck Grassley and Ted Cruz, “but the Democrats filibustered it.”
# 86
# checking Increased encounters at the southwest border in April 2022 compared to April 2020 are attributable to changes in border policy.
# 87
# checking "David Perdue voted with liberals” for $10 trillion “in new debt, his out-of-control federal spending is driving inflation through the roof."
# 88
# checking “We have 76% of Americans living paycheck to paycheck, meaning they are one paycheck away from poverty.”
# 89
# checking Images show Joe Biden surrounded by U.S. Marshals.
# 90
# checking “79% of Planned Parenthood clinics are in minority neighborhoods. This is not by accident. That is by its founder, Margaret Sanger's, eugenicist design."
# 91
# checking “We’re one of the seven nations in the world that allow abortion on demand at 20 weeks.”
# 92
# checking "Kari Lake has been appearing at rallies with neo-Nazis," while "two federal juries have found" Katie Hobbs "guilty of racial discrimination."
# 93
# checking Jackie Chan is dead.
# 94
# checking "Pfizer tries to hide 2.4K full-time hires handling vax injuries."
# 95
# checking “The student debt that is out there, almost 60% of it is graduate school debt.”
# 96
# checking “The Red Cross sells your donated blood to hospitals for $150 and then that hospital charges you thousands for a blood transfusion.”
# 97
# checking “Just passed into law today: You cannot go 5 miles over speed limit” in North Carolina.
# 98
# checking As with people vaccinated against COVID-19, “many people who were NOT vaccinated also experienced zero or mild symptoms.”
# 99
# checking "As compared to last year, Texas has about 15% more power generation capacity."
# 100
# checking Says New Zealand Prime Minister Jacinda Ardern said her country doesn’t have to deal with the “rage of older white men” because “we’ve never allowed Rupert Murdoch to set up a media outlet here.”
# 101
# checking March 2022 moon crash was orchestrated by the government and visible from Earth.
# 102
# checking Fuel containing 15% ethanol will ruin a car engine.
# 103
# checking “Most Americans favor keeping Title 42 in place.”
# 104
# checking "As Ohio treasurer, Josh Mandel loaned your money to Chinese business interests, and Mandel opposed a bill holding Communist China accountable when they cheated and stole American jobs."
# 105
# checking Since taking office, Hochul has passed more than 400 new bills
# 106
# checking Cannabis reform "is supported by the majority of the residents of our state, including a majority of Republicans."
# 107
# checking We’ve reduced crime to its lowest level in 27 years.
# 108
# checking “New York leads the U.S. in population loss.”
# 109
# checking Videos show that Ukraine President Volodymyr Zelenskyy uses cocaine.
# 110
# checking “Kathy Barnette wants to build a statue of Barack Obama right next to the one of Abraham Lincoln on Capitol Hill."
# 111
# checking Georgia Gov. Brian Kemp “allowed 7.5 million ballots to be sent to every registered voter.”
# 112
# checking ABC News altered the Uvalde, Texas, school shooter’s photo to appear more Caucasian.
# 113
# checking Texas is "50th in the nation in mental health care access."
# 114
# checking They passed the flu off as COVID-19, and “they’re going to do the same thing with monkeypox and shingles.”
# 115
# checking “Florida Highway Patrol has a semi-truck … The FHP uses a fleet of three such ‘hidden in plain sight’ trucks to snitch on bad drivers.”
# 116
# checking “The majority of citizens in the country will have no change at all because … most of the population resides in states that have already protected abortion rights.”
# 117
# checking The Supreme Court decision overturning Roe v. Wade "made the United States an outlier among developed nations in the world" on abortion rights.
# 118
# checking Photo shows U.S. Rep. Lauren Boebert with two scantily dressed men.
# 119
# checking “The four big meat packers are raking in record profits … ”
# 120
# checking “SCOTUS overturned the 2020 election.”
# 121
# checking The Wisconsin Supreme Court decision declaring ballot drop boxes illegal "includes the 2020 Presidential Election."
# 122
# checking Sen. Marco Rubio has "one of the worst attendance records in the Senate."
# 123
# checking "In the Wisconsin State Assembly this session, more than 75% of GOP bills received a public hearing. Meanwhile, the GOP allowed less than 2% of Democratic bills to have a hearing."
# 124
# checking "They are literally chopping off the private parts of young kids."
# 125
# checking Image claims to show a list of "Republican members of Congress whose PPP loans were forgiven."
# 126
# checking There’s an unlimited supply of water being generated “deep within the Earth.”
# 127
# checking Queen Elizabeth II was a reptile.
# 128
# checking “The nonpartisan Congressional Budget Office says with the supersized staff, the IRS audit rate ‘would rise for ALL taxpayers’ regardless of income, and would even result in audits of innocent Americans who have paid their taxes and don’t owe the IRS anything.”
# 129
# checking Photo shows Queen Elizabeth II meeting Donald Trump wearing a brooch given to her by Barack Obama.
# 130
# checking Barack Obama urged people on Sept. 10, 2001, to “report to work tomorrow” at the World Trade Center.
# 131
# checking "Val Demings supports abortion up until the moment of birth."
# 132
# checking Three court rulings since May 2022 “have made it clear that it is unconstitutional to ban someone between the ages of 18 and 20 from being able to buy an AR.”
# 133
# checking Every time a Republican has been elected president over the last few decades, House Democrats have objected to the result
# 134
# checking Ballot harvesting “altered the outcome” of a city council election in Yuma County, Arizona.
# 135
# checking Herschel Walker misled about “personally treating 4,500 veterans per year,” about “graduating from college” and about “working in law enforcement.”
# 136
# checking “Iowans are paying $5,000 extra for everyday goods under Biden and Axne’s inflation.”
# 137
# checking Lee County, Florida, wasn't "even in the cone" of Hurricane Ian 72 hours before landfall.
# 138
# checking U.S. Sen. Marco Rubio "has denied climate change."
# 139
# checking If a 12-year-old girl became pregnant because of rape or incest, "Tim Michels would force her to deliver the baby."
# 140
# checking In Arizona, early voting would allow Kari Lake’s opponents to see how many votes they “need to fake to catch up and surpass.”
# 141
# checking Adam Laxalt is “anti-DACA” and “fought against the protections for DACA recipients when he was attorney general.”
# 142
# checking Rep. Tim Ryan “wanted to decriminalize fentanyl.”
# 143
# checking Says Gov. Tony Evers would, “allow the government to use red flag laws to confiscate your firearms without due process.”
# 144
# checking Cheri Beasley “backs tax hikes — even on families making under $75,000.”
# 145
# checking David DePape “stripped down to his underwear, grabbed a hammer, and jogged all the way to Nancy Pelosi’s house.”
# 146
# checking David Schweikert has “been convicted of 11 House ethics violations.”
# 147
# checking “Pennsylvania judge allows ballots to count that are received up until November 14th.”
# 148
# checking In the 2018 Florida governor's race "votes were being stolen by the corrupt election process in Broward. … I sent in the FBI and the U.S. Attorneys, and the ballot theft immediately ended. … I stopped his Election from being stolen."
# 149
# checking Herschel Walker “is heavily funded by the oil and gas industry, raking in more than $140,000 in donations from Big Oil and other energy interests."
# 150
# checking Hitler “didn’t kill 6 million Jews” and “the Holocaust is not what happened.”
# 151
# checking Drone footage confirms Jeffrey Epstein is alive.
# 152
# checking Proposed rule would limit milk for WIC participants
# 153
# checking In Milwaukee, "The (homicide) rate has nearly doubled in the past two years."
# 154
# checking "Historically, our spring elections (including for state Supreme Court) have a smaller turnout associated with them."
# 155
# checking “The USA has a gun homicide rate 26 times higher than our peers.”
# 156
# checking “Scientists warn eggs are causing thousands of people to ‘suddenly’ form blood clots.”
# 157
# checking “Joe Biden’s war on American energy caused this crisis and his only response has been to drain our strategic petroleum reserve to its lowest level since 1983.”
# 158
# checking “Obama imposed stricter rules on trains carrying toxins. Trump killed them.”
# 159
# checking Video shows “the earthquake in Turkey.”
# 160
# checking Canada is to thank for American football.
# 161
# checking "The Biden administration is floating a new” climate strategy: Don't leave your house."
# 162
# checking Video shows U.S. Secret Service agents are demons.
# 163
# checking “Every single county in New York has experienced a federal climate disaster between 2011-2021.”
# 164
# checking Walgreens’ position “has always been” to “dispense Mifepristone in any jurisdiction where it is legally permissible to do so.”
# 165
# checking “More cops are killed responding to domestic violence calls than anything else.”
# 166
# checking “Title 42 and other Trump-era holdovers are forcing migrants into dangerous, overcrowded conditions in Mexico.”
# 167
# checking When discussing education savings accounts, "We would be 31st in the nation to have these policies going forward on behalf of kids.”
# 168
# checking Regarding Trump’s January 2021 telephone call with Georgia election officials, “nobody found anything wrong with that perfect call until a book promotion tour many months later.”
# 169
# checking Pouring soda on raw pork will cause parasites to emerge.
# 170
# checking There is “$500 billion of unspent COVID money” that can be rescinded.
# 171
# checking Gov. Ron DeSantis signed “a last-minute exception into an anti-discrimination law for anyone who also operates a theme park more than 25 acres in Florida,” benefiting Walt Disney Co.
# 172
# checking “Texas Republicans just voted to give a Republican appointee the power to single-handedly CANCEL election results in the state’s largest Democratic county.”
# 173
# checking Addressing the impact of the House GOP debt-ceiling bill on veterans’ programs, "I'm dead serious that we're not cutting veterans, and I mean it."
# 174
# checking Chelsea Clinton said, “It’s time to force-jab every unvaccinated child in America.”
# 175
# checking Minority Leader Robert Reives “sent out a statement … encouraging us to resign and/or (face) a primary challenge.”
# 176
# checking "Latino small businesses are 1 in 4 new businesses, but only 1% of venture capital funding goes to Latino businesses."
# 177
# checking “This year, there have been 13,000 deaths by gun violence. The vast majority, 95% of them, are in inner cities, where you have some of the strictest gun control laws in the country.”
# 178
# checking “(Donald) Trump ran up more debt than any other president in American history.”
# 179
# checking Amazon’s “Utopia” TV series predicted the COVID-19 pandemic and an intentional effort to sterilize humans, showing the pandemic was planned.
# 180
# checking “A Ukrainian tank uses a house as camouflage.”
# 181
# checking Titan submersible passenger Shahzada Dawood is the World Economic Forum’s vice chairman.
# 182
# checking “Miss USA boycotts Miss Universe pageant: ‘I’m not competing against a man.’”
# 183
# checking "Las personas mayores de 65 años con dificultades financieras" pueden calificar para una "flex card" de Medicare para comprar alimentos, pagar trabajo dental y otras necesidades.
# 184
# checking “Putin bans 5G across Russia, destroys all towers.”
# 185
# checking El libro “Fire & Fury” “salió un día después del fuego en Hawaii … Esto es más evidencia de que todo fue planificado”.
# 186
# checking U.S. inflation is "now down close to 3%, the lowest among the world’s leading economies."
# 187
# checking Sen. Rick Scott “wants to … end Social Security and Medicare coverage.”
# 188
# checking The World Economic Forum is calling “for COVID concentration camps.”
# 189
# checking There are "about a half a dozen" transgender athletes competing in Wisconsin K-12 schools.
# 190
# checking “Lego donates model MRI kits to hospitals to help children understand the procedure and reduce their anxiety.”
# 191
# checking “Because of our economic policies we now are reducing inflation.”
# 192
# checking Video shows Elon Musk said South Africans no longer have to work with access to his “platform.”
# 193
# checking Video shows “Israel Zionist blowing up people in hospitals” in 2023.
# 194
# checking “Any American who needs $2,000 a month can get it now” thanks to a new government program.
# 195
# checking New Hampshire has “a worse drug problem per capita than any other state."
# 196
# checking “Last year alone, natural disasters in America caused $178 billion in damages.”
# 197
# checking "Los estadounidenses que ganan menos de $50,000 al año pueden solicitar un seguro médico gratuito".
# 198
# checking "La administración acaba de aprobar este vacío legal, 100% legal, que permite a todos los residentes estadounidenses en buena posición obtener un permiso de portación oculta (de armas) válido en 2023".
# 199
# checking “Florida state government (has the) lowest number of state employees per capita in the country.”
# 200
# checking Taylor Swift was photographed holding a “Trump won, Democrats cheated!” flag at the Grammy Awards.
# 201
# checking Under Joe Biden, there are “record numbers of new Black entrepreneurs.”
# 202
# checking Minnesota incarcerates “about a third of what Wisconsin does.”
# 203
# checking Says expanding Medicaid in Wisconsin would save the state $530 million, which could pay for 3,287 K-12 teachers, or 7.8 educators per district.
# 204
# checking “In April last year, our state unemployment rate hit a record low of 2.4%. Last year, Wisconsin had an all-time lowest number of unemployed workers ever in modern history.”
# 205
# checking “We’ve seen an 800% increase in the Swanton sector, which is the part of the northern border that I represent, in illegal crossings.”

# %%
indxs_baseline_llama2 = []
res_baseline_llama2 = []

for i,row in sampled_data.iterrows():
    
    print(i)
    try:
        out_v0 = run_claim_judge_pipeline(
                text=row['claim'], one_claim = True, search_version=0, llm_to_use = 'llama2', study_mode=False, baseline=True
        )
        indxs_baseline_llama2.append(row['index'])
        res_baseline_llama2.append(out_v0['final_output'])
    except Exception as e:
        print(e)
        indxs_baseline_llama2.append(row['index'])
        res_baseline_llama2.append(None)

judged_politifact_baseline_llama2 = pd.DataFrame(data={'index': indxs_baseline_llama2, 'judgement': res_baseline_llama2, 'API': 'baseline-llama2'})
judged_politifact_baseline_llama2.head()

judged_politifact_baseline_llama2.to_excel('judged_subset_of_politifact_data_llama2_baseline.xlsx')
# Out:
# 0
# checking “Marijuana is currently classified in the same category of drugs as heroin and a more dangerous category than fentanyl or cocaine.”
# 1
# checking President Joe Biden “directed New York AG Witch Hunt” into Donald Trump’s real estate.
# 2
# checking "(The) top issue for college students is the economy."
# 3
# checking “Wisconsin had over 1,400 opioid overdose deaths in 2022.”
# 4
# checking Donald Trump “proposed when he was president” that “he wanted to raise the gas tax up to 25 cents."
# 5
# checking Jimmy Kimmel was on the Jeffrey Epstein list, documents show.
# 6
# checking “Right now, over 70% of federal employees are still working from home three years after COVID."
# 7
# checking Gov. Tony Evers and Democrats "rejected our (Iowa model redistricting) proposal to enact the very plan they originally endorsed."
# 8
# checking Wisconsin Republicans are backing “a nonpartisan redistricting plan based off the Iowa Model. ... Republicans, Democrats, and the Governor pushed this plan last time redistricting happened in 2020.”
# 9
# checking Republicans’ “plan would cut Social Security benefits. … Average benefit cut would be 13%.”
# 10
# checking In Florida, “any woman who has an abortion after six weeks — and any doctor who gives her care — will be guilty of a felony.”
# 11
# checking Potato chips, KitKat bars and Viagra are not taxed in Wisconsin because they are considered "essential."
# 12
# checking U.S. Rep. Mike Johnson is the 45th speaker of the House.
# 13
# checking “In the last 11 months, Customs and Border Patrol has averaged 200,000 apprehensions a month, and you know how many beds we have to detain people at the border? Thirty-eight thousand."
# 14
# checking "Derrick Van Orden is one of the only members of Congress who participated in the deadly January 6th insurrection. He now serves in the building he tried to burn down."
# 15
# checking “Trump controls U.S. military.”
# 16
# checking “Gas prices have skyrocketed since Joe Biden took office and continue to do so everyday.”
# 17
# checking Foreign languages are “not a high priority” nationally
# 18
# checking “The percentage of students that are going to college (in West Virginia) has been declining for five years.”
# 19
# checking Since Joe Biden “has taken office, unemployment in our (Latino) community has been cut in half."
# 20
# checking U.S. aid to Ukraine will continue during a government shutdown, but programs for food stamps, transportation, education, justice, environmental protection and homelessness will not.
# 21
# checking “We know the bank records show that nearly $20 million in payments were directed to the Biden family members and associates through various shell companies.”
# 22
# checking Under Gov. Ron DeSantis, “in the last five years, spending has gone up 30%" in Florida.
# 23
# checking “You can work at some McDonald’s in this country for more money than … signing up for the military.”
# 24
# checking Florida “decided middle school students will be taught that enslaved people benefited from slavery.”
# 25
# checking "Tejas, Florida y otros estados acaban de anunciar que le darán papeles a todos los inmigrantes indocumentados".
# 26
# checking A video shows people holding up their phones to film President Joe Biden, but “every phone there is turned off.”
# 27
# checking World Economic Forum “calls for AI to rewrite Bible, create ‘religions that are actually correct’”
# 28
# checking “Cocaine, porn, evidence of child trafficking found in (Gov. Gretchen) Whitmer’s car.”
# 29
# checking “For African American families in particular, the homeownership rate remains relatively unchanged since 1968, the year the Fair Housing Act was signed into law.”
# 30
# checking Four North Carolina Republicans made “campaign promises” to protect reproductive rights
# 31
# checking Emergency stimulus loans “are finally available to U.S. citizens up to $5,000 even with poor credit.”
# 32
# checking "There is no Biden presidency. The real Biden was executed for his crimes long ago along with Clinton."
# 33
# checking "WOW county swing suburban voters (in Wisconsin) don't vote for Donald Trump.”
# 34
# checking Video shows Sen. Chris Murphy running away because Sen. Ted Cruz said “just shut your mouth.”
# 35
# checking Video shows a crowd erupting and Hillary Clinton crying during a committee hearing.
# 36
# checking "The First Amendment doesn’t allow you to willingly lie."
# 37
# checking "Businesses large and small have led Texas to be ranked the number one state for business every year that I’ve been governor."
# 38
# checking “Harry could be exiled to Botswana after he was deported from the United States due to an expired visa.”
# 39
# checking In Ohio, “there are 75,000 acres of farmland, fertile farmland, that are all now being poured down with acid rain.”
# 40
# checking The sinking of the Titanic was orchestrated by the Rothschilds and J.P. Morgan to kill prominent businessmen who opposed the creation of the Federal Reserve.
# 41
# checking “Classified documents can never be taken out of a (sensitive compartmented information facility), ever.”
# 42
# checking California has twice the population of New York, but spends $260 billion, while New York spends $220 billion.
# 43
# checking Magic Johnson tested positive for HIV "because Fauci’s gain of function study used a contaminated Hepatitis B vaccine."
# 44
# checking “Every single Republican blocked Ketanji Brown Jackson’s SCOTUS appointment.”
# 45
# checking “When the Republicans were in power the last time for eight years, do you know how much discretionary spending increased in those eight years? Zero.”
# 46
# checking Recent blood clots or strokes in four major athletes are an unwanted effect of COVID-19 vaccines.
# 47
# checking Raphael Warnock "believes in no cash bail" and "letting people out of prison that are going to make us prisoners in our own home."
# 48
# checking Photo shows “ballots not counted in California and this is only one polling location. Yet Gavin Newsom was declared governor minutes after polling stations closed.”
# 49
# checking President Joe Biden and Democrats "send a fortune to Ukraine but nothing for our children."
# 50
# checking Katie Hobbs “has voted to double our gas tax.”
# 51
# checking The Pelosis “are refusing to turn over surveillance video of their home.”
# 52
# checking California state Sen. Scott Wiener “doesn’t just want to sterilize California kids, but sterilization of kids everywhere!”
# 53
# checking Catherine Cortez Masto "was the deciding vote” to send COVID-19 stimulus checks to more than 1 million prisoners.
# 54
# checking Says Tim Michels "opposes closing the loophole that allows domestic abusers to buy guns."
# 55
# checking “Mandela Barnes came out in favor of abortion up until the moment of birth.”
# 56
# checking Donald Trump’s “rally just got shut down after no one shows up.”
# 57
# checking Val Demings "voted to allow transgender youth sports and teaching radical gender identity without parental consent."
# 58
# checking “The Obama Foundation stored classified documents in an abandoned furniture warehouse.”
# 59
# checking Sen. Marco Rubio and U.S. Rep. Ron DeSantis “voted against aid for Hurricane Sandy.”
# 60
# checking “Jen Kiggans’ campaign confirmed today that she would support a national abortion ban.”
# 61
# checking “Since 2019, I've successfully lobbied for the funds to add hundreds of school counselors, lowering our student to school counselor ratio by 20%.”
# 62
# checking Says Tim Michels' family foundation "funded an organization that tracks women when they get near abortion clinics … he wants to treat women like they're the criminals."
# 63
# checking “This year, it's going to be over $1.5 trillion (that we’ve) reduced the debt."
# 64
# checking "40% of the folks who have student loans do not have a college diploma, four-year diploma. These are people who are truck drivers and who are nail technicians and nurses’ aides.”
# 65
# checking "Last year the IRS audited Americans earning less than $25,000 a year at five times the rate of other groups."
# 66
# checking Says Republican U.S. Sen. Ron Johnson “called climate change ‘bull----’ during a record heatwave” and “raked in over $700k in fossil fuel cash.”
# 67
# checking Raphael Warnock and Catherine Cortez Masto “voted to allow hundreds of millions of dollars of COVID relief funds to be squandered” on leisure projects.
# 68
# checking "We've cut the deficit by a record $1.5 trillion this year."
# 69
# checking "38,000 Texans had their license to carry denied, revoked, or suspended over the last five years because law enforcement deemed them too dangerous to carry a loaded gun in public. But thanks to Greg Abbott's new law, they don't need a license to carry anymore."
# 70
# checking Video shows Donald Trump at an Alabama rally on July 13, 2022.
# 71
# checking CNN coverage has evidence of the “single most egregious, real-time example of electronic vote fraud.”
# 72
# checking "Milwaukee’s hotels and restaurants are already filled during the summer. The RNC convention will simply replace those who normally visit our city."
# 73
# checking Video claims Moscow turned into “sea of fire after being attacked by two mysterious missiles.”
# 74
# checking Video shows Russian artillery tanks “completely destroyed by Bayraktar TB2 drones” on July 2.
# 75
# checking “When you have unemployment below 4% and inflation above 4%, recession always follows within two years.”
# 76
# checking Says Marjorie Taylor Greene said “246 years ago Jesus Christ performed his miracle of making a single days worth of bullets last 8 days.”
# 77
# checking “In every other major industrial country in the world … inflation is higher.”
# 78
# checking “Wisconsin's archaic abortion ban is older than 20 states."
# 79
# checking Recent research suggests that 15% of abortions are the result of coercion.
# 80
# checking Adam Laxalt "supports eliminating Nevada's protections for legal abortions."
# 81
# checking “In Virginia, Black people are eight times (8X) more likely than white people to die of gun homicide.”
# 82
# checking “Zack Nunn saved over 2,000 Americans abandoned in Afghanistan by leading private rescue missions.”
# 83
# checking CNN is recycling crisis actors in reports about a man dying in Afghanistan in 2021 and at the Uvalde, Texas, school shooting in 2022.
# 84
# checking Aaron Salter Jr. was killed by a mass shooter because he was working on creating a water-powered car engine.
# 85
# checking In 2013, under a Democratic Senate, "a majority of the Senate voted in favor of" gun-related legislation sponsored by Republican Sens. Chuck Grassley and Ted Cruz, “but the Democrats filibustered it.”
# 86
# checking Increased encounters at the southwest border in April 2022 compared to April 2020 are attributable to changes in border policy.
# 87
# checking "David Perdue voted with liberals” for $10 trillion “in new debt, his out-of-control federal spending is driving inflation through the roof."
# 88
# checking “We have 76% of Americans living paycheck to paycheck, meaning they are one paycheck away from poverty.”
# 89
# checking Images show Joe Biden surrounded by U.S. Marshals.
# 90
# checking “79% of Planned Parenthood clinics are in minority neighborhoods. This is not by accident. That is by its founder, Margaret Sanger's, eugenicist design."
# 91
# checking “We’re one of the seven nations in the world that allow abortion on demand at 20 weeks.”
# 92
# checking "Kari Lake has been appearing at rallies with neo-Nazis," while "two federal juries have found" Katie Hobbs "guilty of racial discrimination."
# 93
# checking Jackie Chan is dead.
# 94
# checking "Pfizer tries to hide 2.4K full-time hires handling vax injuries."
# 95
# checking “The student debt that is out there, almost 60% of it is graduate school debt.”
# 96
# checking “The Red Cross sells your donated blood to hospitals for $150 and then that hospital charges you thousands for a blood transfusion.”
# 97
# checking “Just passed into law today: You cannot go 5 miles over speed limit” in North Carolina.
# 98
# checking As with people vaccinated against COVID-19, “many people who were NOT vaccinated also experienced zero or mild symptoms.”
# 99
# checking "As compared to last year, Texas has about 15% more power generation capacity."
# 100
# checking Says New Zealand Prime Minister Jacinda Ardern said her country doesn’t have to deal with the “rage of older white men” because “we’ve never allowed Rupert Murdoch to set up a media outlet here.”
# 101
# checking March 2022 moon crash was orchestrated by the government and visible from Earth.
# 102
# checking Fuel containing 15% ethanol will ruin a car engine.
# 103
# checking “Most Americans favor keeping Title 42 in place.”
# 104
# checking "As Ohio treasurer, Josh Mandel loaned your money to Chinese business interests, and Mandel opposed a bill holding Communist China accountable when they cheated and stole American jobs."
# 105
# checking Since taking office, Hochul has passed more than 400 new bills
# 106
# checking Cannabis reform "is supported by the majority of the residents of our state, including a majority of Republicans."
# 107
# checking We’ve reduced crime to its lowest level in 27 years.
# 108
# checking “New York leads the U.S. in population loss.”
# 109
# checking Videos show that Ukraine President Volodymyr Zelenskyy uses cocaine.
# 110
# checking “Kathy Barnette wants to build a statue of Barack Obama right next to the one of Abraham Lincoln on Capitol Hill."
# 111
# checking Georgia Gov. Brian Kemp “allowed 7.5 million ballots to be sent to every registered voter.”
# 112
# checking ABC News altered the Uvalde, Texas, school shooter’s photo to appear more Caucasian.
# 113
# checking Texas is "50th in the nation in mental health care access."
# 114
# checking They passed the flu off as COVID-19, and “they’re going to do the same thing with monkeypox and shingles.”
# 115
# checking “Florida Highway Patrol has a semi-truck … The FHP uses a fleet of three such ‘hidden in plain sight’ trucks to snitch on bad drivers.”
# 116
# checking “The majority of citizens in the country will have no change at all because … most of the population resides in states that have already protected abortion rights.”
# 117
# checking The Supreme Court decision overturning Roe v. Wade "made the United States an outlier among developed nations in the world" on abortion rights.
# 118
# checking Photo shows U.S. Rep. Lauren Boebert with two scantily dressed men.
# 119
# checking “The four big meat packers are raking in record profits … ”
# 120
# checking “SCOTUS overturned the 2020 election.”
# 121
# checking The Wisconsin Supreme Court decision declaring ballot drop boxes illegal "includes the 2020 Presidential Election."
# 122
# checking Sen. Marco Rubio has "one of the worst attendance records in the Senate."
# 123
# checking "In the Wisconsin State Assembly this session, more than 75% of GOP bills received a public hearing. Meanwhile, the GOP allowed less than 2% of Democratic bills to have a hearing."
# 124
# checking "They are literally chopping off the private parts of young kids."
# 125
# checking Image claims to show a list of "Republican members of Congress whose PPP loans were forgiven."
# 126
# checking There’s an unlimited supply of water being generated “deep within the Earth.”
# 127
# checking Queen Elizabeth II was a reptile.
# 128
# checking “The nonpartisan Congressional Budget Office says with the supersized staff, the IRS audit rate ‘would rise for ALL taxpayers’ regardless of income, and would even result in audits of innocent Americans who have paid their taxes and don’t owe the IRS anything.”
# 129
# checking Photo shows Queen Elizabeth II meeting Donald Trump wearing a brooch given to her by Barack Obama.
# 130
# checking Barack Obama urged people on Sept. 10, 2001, to “report to work tomorrow” at the World Trade Center.
# 131
# checking "Val Demings supports abortion up until the moment of birth."
# 132
# checking Three court rulings since May 2022 “have made it clear that it is unconstitutional to ban someone between the ages of 18 and 20 from being able to buy an AR.”
# 133
# checking Every time a Republican has been elected president over the last few decades, House Democrats have objected to the result
# 134
# checking Ballot harvesting “altered the outcome” of a city council election in Yuma County, Arizona.
# 135
# checking Herschel Walker misled about “personally treating 4,500 veterans per year,” about “graduating from college” and about “working in law enforcement.”
# 136
# checking “Iowans are paying $5,000 extra for everyday goods under Biden and Axne’s inflation.”
# 137
# checking Lee County, Florida, wasn't "even in the cone" of Hurricane Ian 72 hours before landfall.
# 138
# checking U.S. Sen. Marco Rubio "has denied climate change."
# 139
# checking If a 12-year-old girl became pregnant because of rape or incest, "Tim Michels would force her to deliver the baby."
# 140
# checking In Arizona, early voting would allow Kari Lake’s opponents to see how many votes they “need to fake to catch up and surpass.”
# 141
# checking Adam Laxalt is “anti-DACA” and “fought against the protections for DACA recipients when he was attorney general.”
# 142
# checking Rep. Tim Ryan “wanted to decriminalize fentanyl.”
# 143
# checking Says Gov. Tony Evers would, “allow the government to use red flag laws to confiscate your firearms without due process.”
# 144
# checking Cheri Beasley “backs tax hikes — even on families making under $75,000.”
# 145
# checking David DePape “stripped down to his underwear, grabbed a hammer, and jogged all the way to Nancy Pelosi’s house.”
# 146
# checking David Schweikert has “been convicted of 11 House ethics violations.”
# 147
# checking “Pennsylvania judge allows ballots to count that are received up until November 14th.”
# 148
# checking In the 2018 Florida governor's race "votes were being stolen by the corrupt election process in Broward. … I sent in the FBI and the U.S. Attorneys, and the ballot theft immediately ended. … I stopped his Election from being stolen."
# 149
# checking Herschel Walker “is heavily funded by the oil and gas industry, raking in more than $140,000 in donations from Big Oil and other energy interests."
# 150
# checking Hitler “didn’t kill 6 million Jews” and “the Holocaust is not what happened.”
# 151
# checking Drone footage confirms Jeffrey Epstein is alive.
# 152
# checking Proposed rule would limit milk for WIC participants
# 153
# checking In Milwaukee, "The (homicide) rate has nearly doubled in the past two years."
# 154
# checking "Historically, our spring elections (including for state Supreme Court) have a smaller turnout associated with them."
# 155
# checking “The USA has a gun homicide rate 26 times higher than our peers.”
# 156
# checking “Scientists warn eggs are causing thousands of people to ‘suddenly’ form blood clots.”
# 157
# checking “Joe Biden’s war on American energy caused this crisis and his only response has been to drain our strategic petroleum reserve to its lowest level since 1983.”
# 158
# checking “Obama imposed stricter rules on trains carrying toxins. Trump killed them.”
# 159
# checking Video shows “the earthquake in Turkey.”
# 160
# checking Canada is to thank for American football.
# 161
# checking "The Biden administration is floating a new” climate strategy: Don't leave your house."
# 162
# checking Video shows U.S. Secret Service agents are demons.
# 163
# checking “Every single county in New York has experienced a federal climate disaster between 2011-2021.”
# 164
# checking Walgreens’ position “has always been” to “dispense Mifepristone in any jurisdiction where it is legally permissible to do so.”
# 165
# checking “More cops are killed responding to domestic violence calls than anything else.”
# 166
# checking “Title 42 and other Trump-era holdovers are forcing migrants into dangerous, overcrowded conditions in Mexico.”
# 167
# checking When discussing education savings accounts, "We would be 31st in the nation to have these policies going forward on behalf of kids.”
# 168
# checking Regarding Trump’s January 2021 telephone call with Georgia election officials, “nobody found anything wrong with that perfect call until a book promotion tour many months later.”
# 169
# checking Pouring soda on raw pork will cause parasites to emerge.
# 170
# checking There is “$500 billion of unspent COVID money” that can be rescinded.
# 171
# checking Gov. Ron DeSantis signed “a last-minute exception into an anti-discrimination law for anyone who also operates a theme park more than 25 acres in Florida,” benefiting Walt Disney Co.
# 172
# checking “Texas Republicans just voted to give a Republican appointee the power to single-handedly CANCEL election results in the state’s largest Democratic county.”
# 173
# checking Addressing the impact of the House GOP debt-ceiling bill on veterans’ programs, "I'm dead serious that we're not cutting veterans, and I mean it."
# 174
# checking Chelsea Clinton said, “It’s time to force-jab every unvaccinated child in America.”
# 175
# checking Minority Leader Robert Reives “sent out a statement … encouraging us to resign and/or (face) a primary challenge.”
# 176
# checking "Latino small businesses are 1 in 4 new businesses, but only 1% of venture capital funding goes to Latino businesses."
# 177
# checking “This year, there have been 13,000 deaths by gun violence. The vast majority, 95% of them, are in inner cities, where you have some of the strictest gun control laws in the country.”
# 178
# checking “(Donald) Trump ran up more debt than any other president in American history.”
# 179
# checking Amazon’s “Utopia” TV series predicted the COVID-19 pandemic and an intentional effort to sterilize humans, showing the pandemic was planned.
# 180
# checking “A Ukrainian tank uses a house as camouflage.”
# 181
# checking Titan submersible passenger Shahzada Dawood is the World Economic Forum’s vice chairman.
# 182
# checking “Miss USA boycotts Miss Universe pageant: ‘I’m not competing against a man.’”
# 183
# checking "Las personas mayores de 65 años con dificultades financieras" pueden calificar para una "flex card" de Medicare para comprar alimentos, pagar trabajo dental y otras necesidades.
# 184
# checking “Putin bans 5G across Russia, destroys all towers.”
# 185
# checking El libro “Fire & Fury” “salió un día después del fuego en Hawaii … Esto es más evidencia de que todo fue planificado”.
# 186
# checking U.S. inflation is "now down close to 3%, the lowest among the world’s leading economies."
# 187
# checking Sen. Rick Scott “wants to … end Social Security and Medicare coverage.”
# 188
# checking The World Economic Forum is calling “for COVID concentration camps.”
# 189
# checking There are "about a half a dozen" transgender athletes competing in Wisconsin K-12 schools.
# 190
# checking “Lego donates model MRI kits to hospitals to help children understand the procedure and reduce their anxiety.”
# 191
# checking “Because of our economic policies we now are reducing inflation.”
# 192
# checking Video shows Elon Musk said South Africans no longer have to work with access to his “platform.”
# 193
# checking Video shows “Israel Zionist blowing up people in hospitals” in 2023.
# 194
# checking “Any American who needs $2,000 a month can get it now” thanks to a new government program.
# 195
# checking New Hampshire has “a worse drug problem per capita than any other state."
# 196
# checking “Last year alone, natural disasters in America caused $178 billion in damages.”
# 197
# checking "Los estadounidenses que ganan menos de $50,000 al año pueden solicitar un seguro médico gratuito".
# 198
# checking "La administración acaba de aprobar este vacío legal, 100% legal, que permite a todos los residentes estadounidenses en buena posición obtener un permiso de portación oculta (de armas) válido en 2023".
# 199
# checking “Florida state government (has the) lowest number of state employees per capita in the country.”
# 200
# checking Taylor Swift was photographed holding a “Trump won, Democrats cheated!” flag at the Grammy Awards.
# 201
# checking Under Joe Biden, there are “record numbers of new Black entrepreneurs.”
# 202
# checking Minnesota incarcerates “about a third of what Wisconsin does.”
# 203
# checking Says expanding Medicaid in Wisconsin would save the state $530 million, which could pay for 3,287 K-12 teachers, or 7.8 educators per district.
# 204
# checking “In April last year, our state unemployment rate hit a record low of 2.4%. Last year, Wisconsin had an all-time lowest number of unemployed workers ever in modern history.”
# 205
# checking “We’ve seen an 800% increase in the Swanton sector, which is the part of the northern border that I represent, in illegal crossings.”
